# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("C:\\Users\\bhoom\\Downloads\\Dataset.csv", encoding="latin1")
df
# Out:
# C:\Users\bhoom\AppData\Local\Temp\ipykernel_16496\2017682602.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("C:\\Users\\bhoom\\Downloads\\Dataset.csv", encoding="latin1")
#                                              Product_name      Price Rate  \
# 0       Crompton 75 L Desert Air Cooler??(White, Tea...  ??10,499    5
# 1       Crompton 75 L Desert Air Cooler??(White, Tea...  ??10,499    4
# 2       Crompton 75 L Desert Air Cooler??(White, Tea...  ??10,499    5
# 3       Crompton 75 L Desert Air Cooler??(White, Tea...  ??10,499    5
# 4       Crompton 75 L Desert Air Cooler??(White, Tea...  ??10,499    4
# ...                                                   ...        ...  ...
# 363256  NIVEA Soft Light Moisturizer for Face, Hand & ...     ??142  5.0
# 363257  NIVEA Soft Light Moisturizer for Face, Hand & ...     ??142  5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363261 entries, 0 to 363260
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Product_name  363246 non-null  object
#  1   Price         363245 non-null  object
#  2   Rate          363245 non-null  object
#  3   Review        363239 non-null  object
#  4   Summary       361239 non-null  object
# dtypes: object(5)
# memory usage: 13.9+ MB

# %%
df.columns
# Out:
# Index(['Product_name', 'Price', 'Rate', 'Review', 'Summary'], dtype='object')

# %%
df.shape
# Out:
# (363261, 5)

# %% [markdown]
# ## Product_name

# %%
df["Product_name"].isna().sum()
# Out:
# np.int64(15)

# %%
df = df.dropna(subset=["Product_name"])

# %%
df["Product_name"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Product_name"].duplicated().sum()
# Out:
# np.int64(362071)

# %%
df["Product_name"].unique()
# Out:
# array(['Crompton 75 L Desert Air Cooler?\x98?\x98(White, Teal, ACGC-DAC751)',
#        'Candes 12 L Room/Personal Air Cooler?\x98?\x98(White, Black, Elegant High Speed-Honey Comb Cooling Pad & Ice Chamber, Blower)',
#        'Crompton 88 L Desert Air Cooler with Honeycomb Cooling Pad?\x98?\x98(White, Teal, ACGC-DAC881)',
#        ...,
#        'URBANYOG Hair Removal Cream Spray for Womens Hand, Leg & Under Arm, Painless Hair Removal Spray?\x98?\x98(200 ml)',
#        'NIVEA Soft Light Moisturizer for Face, Hand & Body, Non-Sticky Cream with Vitamin E & Jojoba Oil?\x98?\x98(100 ml)',
#        '\x1a'], shape=(1175,), dtype=object)

# %%
df["Product_name"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Crompton 75 L Desert Air Cooler??(White, Tea...
# 1         Crompton 75 L Desert Air Cooler??(White, Tea...
# 2         Crompton 75 L Desert Air Cooler??(White, Tea...
# 3         Crompton 75 L Desert Air Cooler??(White, Tea...
# 4         Crompton 75 L Desert Air Cooler??(White, Tea...
#                                 ...
# 363256    NIVEA Soft Light Moisturizer for Face, Hand & ...
# 363257    NIVEA Soft Light Moisturizer for Face, Hand & ...
# 363258    NIVEA Soft Light Moisturizer for Face, Hand & ...
# 363259    NIVEA Soft Light Moisturizer for Face, Hand & ...
# 363260
# Name: Product_name, Length: 363246, dtype: object>

# %% [markdown]
# ## Price

# %%
df["Price"].isna().sum()
# Out:
# np.int64(1)

# %%
df= df.dropna(subset=["Price"])

# %%
df["Price"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Price"].duplicated().sum()
# Out:
# np.int64(362536)

# %%
df["Price"].unique()
# Out:
# array(['\x9f??10,499', '\x9f??3,490', '\x9f??9,499', '\x9f??13,999',
#        '\x9f??6,299', '\x9f??5,249', '\x9f??5,990', '\x9f??7,499',
#        '\x9f??1,097', '\x9f??1,095', '\x9f??655', '\x9f??2,969',
#        '\x9f??495', '\x9f??549', '\x9f??700', '\x9f??339', '\x9f??271',
#        '\x9f??409', '\x9f??229', '\x9f??228', '\x9f??258', '\x9f??329',
#        '\x9f??599', '\x9f??901', '\x9f??529', '\x9f??499', '\x9f??840',
#        '\x9f??3,499', '\x9f??5,999', '\x9f??4,999', '\x9f??799',
#        '\x9f??1,699', '\x9f??1,799', '\x9f??1,999', '\x9f??1,499',
#        '\x9f??9,999', '\x9f??1,099', '\x9f??899', '\x9f??1,199',
#        '\x9f??3,999', '\x9f??4,990', '\x9f??526', '\x9f??1,299',
#        '\x9f??3,699', '\x9f??435', '\x9f??30,999', '???399', '???249',
#        '???229', '???259', '???219', '???295', '???639', '???519',
#        '???217', '???199', '???220', '??????322', '??????234',
#        '??????342', '??????389', '??????143', '??????1,349', '??????499',
# ...

# %%
df["Price"].dtypes
# Out:
# dtype('O')

# %%
df["Price"] = df["Price"].str.replace(r"[^0-9]", "", regex=True)
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")

# %%
df["Price"].unique()
# Out:
# array([1.0499e+04, 3.4900e+03, 9.4990e+03, 1.3999e+04, 6.2990e+03,
#        5.2490e+03, 5.9900e+03, 7.4990e+03, 1.0970e+03, 1.0950e+03,
#        6.5500e+02, 2.9690e+03, 4.9500e+02, 5.4900e+02, 7.0000e+02,
#        3.3900e+02, 2.7100e+02, 4.0900e+02, 2.2900e+02, 2.2800e+02,
#        2.5800e+02, 3.2900e+02, 5.9900e+02, 9.0100e+02, 5.2900e+02,
#        4.9900e+02, 8.4000e+02, 3.4990e+03, 5.9990e+03, 4.9990e+03,
#        7.9900e+02, 1.6990e+03, 1.7990e+03, 1.9990e+03, 1.4990e+03,
#        9.9990e+03, 1.0990e+03, 8.9900e+02, 1.1990e+03, 3.9990e+03,
#        4.9900e+03, 5.2600e+02, 1.2990e+03, 3.6990e+03, 4.3500e+02,
#        3.0999e+04, 3.9900e+02, 2.4900e+02, 2.5900e+02, 2.1900e+02,
#        2.9500e+02, 6.3900e+02, 5.1900e+02, 2.1700e+02, 1.9900e+02,
#        2.2000e+02, 3.2200e+02, 2.3400e+02, 3.4200e+02, 3.8900e+02,
#        1.4300e+02, 1.3490e+03, 3.3200e+02, 2.9900e+02, 3.3300e+02,
#        5.4100e+02, 3.5900e+02, 5.6600e+02, 3.3400e+02, 3.2500e+02,
# ...

# %%
np.set_printoptions(suppress=True)
print(df["Price"].unique())
# Out:
# [ 10499.   3490.   9499.  13999.   6299.   5249.   5990.   7499.   1097.
#    1095.    655.   2969.    495.    549.    700.    339.    271.    409.
#     229.    228.    258.    329.    599.    901.    529.    499.    840.
#    3499.   5999.   4999.    799.   1699.   1799.   1999.   1499.   9999.
#    1099.    899.   1199.   3999.   4990.    526.   1299.   3699.    435.
#   30999.    399.    249.    259.    219.    295.    639.    519.    217.
#     199.    220.    322.    234.    342.    389.    143.   1349.    332.
#     299.    333.    541.    359.    566.    334.    325.    379.    350.
#     999.    563.    341.    546.    338.    540.    640.    616.    699.
#     675.    678.   1094.    475.   9990.  14299.   5298.   7599.  11999.
#     169.    619.   1298.    545.   1260.    270.   1233.    189.    269.
#     176.    222.    149.    681.    279.    507.    190.    263.    246.
#     251.    193.    158.    289.    375.    226.    425.    302.     59.
# ...

# %%
df["Price"].dtypes
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['Product_name', 'Price', 'Rate', 'Review', 'Summary'], dtype='object')

# %%
df["Price"].isna().sum()
# Out:
# np.int64(3)

# %%
df= df.dropna(subset=["Price"])

# %%
df["Price"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Price"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         10499.0
# 1         10499.0
# 2         10499.0
# 3         10499.0
# 4         10499.0
#            ...
# 363255      142.0
# 363256      142.0
# 363257      142.0
# 363258      142.0
# 363259      142.0
# Name: Price, Length: 363242, dtype: float64>

# %% [markdown]
# ## Rate

# %%
df["Rate"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Rate"].dtypes
# Out:
# dtype('O')

# %%
df["Rate"].unique()
# Out:
# array(['5', '4', '3', '1', '2',
#        'Pigeon Favourite Electric Kettle????(1.5 L, Silver, Black)',
#        'Bajaj DX 2 L/W Dry Iron',
#        'Nova Plus Amaze NI 10 1100 W Dry Iron????(Grey & Turquoise)', 5.0,
#        4.0, 1.0, 3.0, 2.0], dtype=object)

# %%
df["Rate"] = pd.to_numeric(df["Rate"], errors="coerce")

# %%
df["Rate"].isna().sum()
# Out:
# np.int64(3)

# %%
df = df.dropna(subset=["Rate"])

# %%
df["Rate"].unique()
# Out:
# array([5., 4., 3., 1., 2.])

# %%
df["Rate"].dtype
# Out:
# dtype('float64')

# %%
df["Rate"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         5.0
# 1         4.0
# 2         5.0
# 3         5.0
# 4         4.0
#          ...
# 363255    5.0
# 363256    5.0
# 363257    5.0
# 363258    5.0
# 363259    4.0
# Name: Rate, Length: 363239, dtype: float64>

# %% [markdown]
# ## Review

# %%
df["Review"].isna().sum()
# Out:
# np.int64(6)

# %%
df= df.dropna(subset=["Review"])

# %%
df["Review"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Review"].dtype
# Out:
# dtype('O')

# %%
df["Review"].unique()
# Out:
# array(['Simply awesome',
#        'Worth the money . Desert Cooler live up to the Name .',
#        'Worth every penny', ..., 'Mast', 'Good in budget', 'Well!!!'],
#       shape=(3837,), dtype=object)

# %% [markdown]
# ## Summary

# %%
df["Summary"].isna().sum()
# Out:
# np.int64(2004)

# %%
df = df.dropna(subset=["Summary"])

# %%
df["Summary"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Summary"].dtype
# Out:
# dtype('O')

# %%
df["Summary"].unique()
# Out:
# array(["it's really worth every single penny. it works like one ton AC provided that your room has proper ventilation.  I generally keep cooler near to window so that it can pull fresh air from outside and as a result I get very cool air. one more suggestion,  please don't buy cooler which are equipped with a blower fan. Always go for the cooler equipped with metal fan like this one.  In one word, this Compton cooler is Amazing. if you find the review helpful, please thumps up. Happy summer! ????",
# ...

# %%
df
# Out:
#                                              Product_name    Price  Rate  \
# 0       Crompton 75 L Desert Air Cooler??(White, Tea...  10499.0   5.0
# 1       Crompton 75 L Desert Air Cooler??(White, Tea...  10499.0   4.0
# 2       Crompton 75 L Desert Air Cooler??(White, Tea...  10499.0   5.0
# 3       Crompton 75 L Desert Air Cooler??(White, Tea...  10499.0   5.0
# 4       Crompton 75 L Desert Air Cooler??(White, Tea...  10499.0   4.0
# ...                                                   ...      ...   ...
# 363255  NIVEA Soft Light Moisturizer for Face, Hand & ...    142.0   5.0
# 363256  NIVEA Soft Light Moisturizer for Face, Hand & ...    142.0   5.0
# 363257  NIVEA Soft Light Moisturizer for Face, Hand & ...    142.0   5.0
# 363258  NIVEA Soft Light Moisturizer for Face, Hand & ...    142.0   5.0
# 363259  NIVEA Soft Light Moisturizer for Face, Hand & ...    142.0   4.0
#
#                                                    Review  \
# ...

# %%
df.to_csv("Flipkart_prod_rev_cleaned.csv", index=False)
