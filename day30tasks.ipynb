# %%
# Challenge 1 – Complete Data Cleaning
# Your manager gives you a messy dataset.
# Perform all of the following:
# • Load the dataset.
# • Display dataset information.
# • Find missing values.
# • Remove duplicate rows.
# • Fill missing values:
# o Age → median
# o Balance → mean
# • Rename:
# o Target → CustomerStatus
# o AnnualIncome → Income
# • Display the first 15 rows.
# Methods expected:
# read_csv()
# info()
# isnull()
# drop_duplicates()
# median()
# mean()
# fillna()
# rename()
# head()

import pandas as pd

df = pd.read_csv("C:\\Users\\bhoom\\Downloads\\Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID       0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015     True
# 1016     True
# 1017     True
# 1018     True
# 1019     True
# Length: 1020, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
# ..          ...   ...           ...       ...          ...        ...     ...
# 995       10996  34.0       81731.0     40980          761  181465.65       5
# 996       10997  47.0       42475.0      1176          780   26640.99       5
# 997       10998  31.0      120531.0     46929          733  147220.82       4
# 998       10999  21.0       33661.0     22314          540   94186.48       5
# 999       11000  63.0       31930.0       851          559  100908.40       6
#
# ...

# %%
age_median = df['Age'].median()
age_median

df['Age'] = df['Age'].fillna(age_median)
df['Age'] = df['Age'].astype("int")
df['Age']
df
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore  Balance  Tenure  \
# 0          10001   58       49184.0      2139          581    97523       2
# 1          10002   65      162964.0      6197          732     6356       1
# 2          10003   56       26956.0     37281          503   143203       8
# 3          10004   55       92926.0       925          463   139627       5
# 4          10005   66      108236.0      7198          394    75985       5
# ...          ...  ...           ...       ...          ...      ...     ...
# 1015       10450   43      173620.0      7121          644    60353       2
# 1016       10753   25       54490.0     13794          303   124512       4
# 1017       10810   49       82062.0     47170          813    53850       8
# 1018       10267   38           NaN     10424          722   138100       6
# 1019       10059   62       97504.0     36833          430    97523      10
#
#      Geography  Gender    Segment Target
# ...

# %%
Balance_mean = df['Balance'].mean()
Balance_mean

df['Balance']=df['Balance'].fillna(Balance_mean)
df['Balance']=df['Balance'].astype("int")
df['Balance']
df
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore  Balance  Tenure  \
# 0          10001   58       49184.0      2139          581    97523       2
# 1          10002   65      162964.0      6197          732     6356       1
# 2          10003   56       26956.0     37281          503   143203       8
# 3          10004   55       92926.0       925          463   139627       5
# 4          10005   66      108236.0      7198          394    75985       5
# ...          ...  ...           ...       ...          ...      ...     ...
# 1015       10450   43      173620.0      7121          644    60353       2
# 1016       10753   25       54490.0     13794          303   124512       4
# 1017       10810   49       82062.0     47170          813    53850       8
# 1018       10267   38           NaN     10424          722   138100       6
# 1019       10059   62       97504.0     36833          430    97523      10
#
#      Geography  Gender    Segment Target
# ...

# %%
df.rename(columns = {"Target":"CustomerStatus",
                     "AnnualIncome":"Income"},inplace = True)
df
# Out:
#       CustomerID  Age    Income  Spending  CreditScore  Balance  Tenure  \
# 0          10001   58   49184.0      2139          581    97523       2
# 1          10002   65  162964.0      6197          732     6356       1
# 2          10003   56   26956.0     37281          503   143203       8
# 3          10004   55   92926.0       925          463   139627       5
# 4          10005   66  108236.0      7198          394    75985       5
# ...          ...  ...       ...       ...          ...      ...     ...
# 1015       10450   43  173620.0      7121          644    60353       2
# 1016       10753   25   54490.0     13794          303   124512       4
# 1017       10810   49   82062.0     47170          813    53850       8
# 1018       10267   38       NaN     10424          722   138100       6
# 1019       10059   62   97504.0     36833          430    97523      10
#
#      Geography  Gender    Segment CustomerStatus
# 0       France    Male        SME           Stay
# ...

# %%
df.head(15)
# Out:
#     CustomerID  Age    Income  Spending  CreditScore  Balance  Tenure  \
# 0        10001   58   49184.0      2139          581    97523       2
# 1        10002   65  162964.0      6197          732     6356       1
# 2        10003   56   26956.0     37281          503   143203       8
# 3        10004   55   92926.0       925          463   139627       5
# 4        10005   66  108236.0      7198          394    75985       5
# 5        10006   69   31390.0     48323          770   107245       6
# 6        10007   58  182141.0     24200          891    38457       1
# 7        10008   67   95861.0      5729          538   173296       6
# 8        10009   41   62638.0     24760          663    41901       4
# 9        10010   22  179680.0     42113          475   106827       3
# 10       10011   44  187772.0     45599          870    43923       5
# 11       10012   69  102694.0     26790          574    13237       9
# ...

# %%
# Challenge 2 – Banking Report
# The bank wants a numeric report.
# Tasks
# • Select only numeric columns.
# • Display summary statistics.
# • Convert Age and CreditScore to float.
# • Display information again.

df1=df.select_dtypes(["int","float"])
df1.describe()
# Out:
#          CustomerID          Age         Income      Spending  CreditScore  \
# count   1020.000000  1020.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112505.928645  25232.615686   602.659804
# std      288.022115    15.136428   52303.362541  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   66149.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  158000.500000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1020.000000  1020.000000
# mean    97523.041176     5.261765
# std     54382.352688     3.185330
# min       547.000000     0.000000
# 25%     52145.500000     2.000000
# 50%     97523.000000     5.000000
# 75%    142086.000000     8.000000
# ...

# %%
df1['Age']=df1['Age'].astype("float")
df1
# Out:
#       CustomerID   Age    Income  Spending  CreditScore  Balance  Tenure
# 0          10001  58.0   49184.0      2139          581    97523       2
# 1          10002  65.0  162964.0      6197          732     6356       1
# 2          10003  56.0   26956.0     37281          503   143203       8
# 3          10004  55.0   92926.0       925          463   139627       5
# 4          10005  66.0  108236.0      7198          394    75985       5
# ...          ...   ...       ...       ...          ...      ...     ...
# 1015       10450  43.0  173620.0      7121          644    60353       2
# 1016       10753  25.0   54490.0     13794          303   124512       4
# 1017       10810  49.0   82062.0     47170          813    53850       8
# 1018       10267  38.0       NaN     10424          722   138100       6
# 1019       10059  62.0   97504.0     36833          430    97523      10
#
# [1020 rows x 7 columns]

# %%
df1['CreditScore']=df1['CreditScore'].astype("float")
df1
# Out:
#       CustomerID   Age    Income  Spending  CreditScore  Balance  Tenure
# 0          10001  58.0   49184.0      2139        581.0    97523       2
# 1          10002  65.0  162964.0      6197        732.0     6356       1
# 2          10003  56.0   26956.0     37281        503.0   143203       8
# 3          10004  55.0   92926.0       925        463.0   139627       5
# 4          10005  66.0  108236.0      7198        394.0    75985       5
# ...          ...   ...       ...       ...          ...      ...     ...
# 1015       10450  43.0  173620.0      7121        644.0    60353       2
# 1016       10753  25.0   54490.0     13794        303.0   124512       4
# 1017       10810  49.0   82062.0     47170        813.0    53850       8
# 1018       10267  38.0       NaN     10424        722.0   138100       6
# 1019       10059  62.0   97504.0     36833        430.0    97523      10
#
# [1020 rows x 7 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   1020 non-null   int64
#  1   Age          1020 non-null   float64
#  2   Income       967 non-null    float64
#  3   Spending     1020 non-null   int64
#  4   CreditScore  1020 non-null   float64
#  5   Balance      1020 non-null   int64
#  6   Tenure       1020 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 55.9 KB

# %%
# Challenge 3 – Duplicate Investigation
# Find duplicate customers.
# Then
# • Count duplicate rows.
# • Remove duplicates.
# • Print information before and after removing duplicates.
# • Show the last 20 rows.

df.duplicated().sum()
df.tail(20)
# Out:
#       CustomerID  Age    Income  Spending  CreditScore  Balance  Tenure  \
# 1000       10643   41  125012.0     18825          761    35977       2
# 1001       10763   56  102965.0     17517          838   115028       9
# 1002       10910   66  118506.0      6296          306    81892       4
# 1003       10200   19  115052.0     20741          484   190233       5
# 1004       10587   29       NaN     40255          383   168358       2
# 1005       10798   22  176830.0      7626          688    65481      10
# 1006       10653   32       NaN     21266          598   142086       9
# 1007       10756   53   74430.0      3705          489    29651      10
# 1008       10417   70   40417.0     37956          681    23880      10
# 1009       10499   34  166546.0     12497          643   130886       3
# 1010       10515   62  199762.0     41808          309    60223      10
# 1011       10457   44   63604.0     27633          804   176354       5
# ...

# %%
df1=df.drop_duplicates()
df1.tail(20)
# Out:
#      CustomerID  Age    Income  Spending  CreditScore  Balance  Tenure  \
# 980       10981   41  199633.0      8498          847   173390       7
# 981       10982   34   98876.0      6414          541    59484       2
# 982       10983   69  188933.0     27126          334    97523       1
# 983       10984   44  107221.0     47514          732   175352       1
# 984       10985   50   37397.0     23559          730   120423       8
# 985       10986   62   27169.0      3914          488   126031      10
# 986       10987   30  184704.0     20524          621   115161       1
# 987       10988   63  190178.0      9025          720   158528       5
# 988       10989   26   88335.0     11869          635   159905       3
# 989       10990   29  123152.0     25228          884    44897       0
# 990       10991   58   79954.0      6331          773    39653       2
# 991       10992   45       NaN     17549          452    17812       5
# ...

# %%
# Challenge 4 – HR Department
# HR wants better column names.
# Rename
# CustomerID → Employee_ID
# Age → EmployeeAge
# Gender → EmployeeGender
# AnnualIncome → Salary
# Target → PromotionStatus
# Then
# • Add prefix
# HR_
# to every column.
# Display 10 random records.


df = pd.read_csv("C:\\Users\\bhoom\\Downloads\\Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df.rename(columns = {"CustomerID":"Employee_ID",
                      "Age":"EmployeeAge",
                      "Gender":"EmployeeGender",
                      "AnnualIncome":"Salary",
                      "Target":"PromotionStatus"},inplace = True)

df
# Out:
#       Employee_ID  EmployeeAge    Salary  Spending  CreditScore    Balance  \
# 0           10001         58.0   49184.0      2139          581        NaN
# 1           10002         65.0  162964.0      6197          732    6356.54
# 2           10003         56.0   26956.0     37281          503  143203.92
# 3           10004         55.0   92926.0       925          463  139627.88
# 4           10005         66.0  108236.0      7198          394   75985.46
# ...           ...          ...       ...       ...          ...        ...
# 1015        10450         43.0  173620.0      7121          644   60353.03
# 1016        10753         25.0   54490.0     13794          303  124512.07
# 1017        10810         49.0   82062.0     47170          813   53850.09
# 1018        10267         38.0       NaN     10424          722  138100.05
# 1019        10059         62.0   97504.0     36833          430        NaN
#
#       Tenure Geography EmployeeGender    Segment PromotionStatus
# ...

# %%
df.add_prefix("HR_")
# Out:
#       HR_Employee_ID  HR_EmployeeAge  HR_Salary  HR_Spending  HR_CreditScore  \
# 0              10001            58.0    49184.0         2139             581
# 1              10002            65.0   162964.0         6197             732
# 2              10003            56.0    26956.0        37281             503
# 3              10004            55.0    92926.0          925             463
# 4              10005            66.0   108236.0         7198             394
# ...              ...             ...        ...          ...             ...
# 1015           10450            43.0   173620.0         7121             644
# 1016           10753            25.0    54490.0        13794             303
# 1017           10810            49.0    82062.0        47170             813
# 1018           10267            38.0        NaN        10424             722
# 1019           10059            62.0    97504.0        36833             430
#
# ...

# %%
df.sample(10)
# Out:
#      Employee_ID  EmployeeAge    Salary  Spending  CreditScore    Balance  \
# 641        10642         57.0  109940.0     24481          488   99754.00
# 822        10823         66.0       NaN      3942          471   92802.99
# 989        10990         29.0  123152.0     25228          884   44897.43
# 53         10054         43.0  198131.0     35641          639  187847.43
# 539        10540         40.0  186110.0     19635          860  104397.02
# 661        10662         46.0  100705.0     24471          722   51961.41
# 982        10983         69.0  188933.0     27126          334        NaN
# 705        10706         22.0  105116.0     32123          477   97655.28
# 498        10499         34.0  166546.0     12497          643  130886.93
# 906        10907         40.0  100762.0     29701          874   17519.73
#
#      Tenure Geography EmployeeGender    Segment PromotionStatus
# 641       3    Canada          Other  Corporate           Churn
# ...

# %%
# Challenge 5 – Finance Cleaning
# Finance department reports missing values.
# Tasks
# Fill
# AnnualIncome → Median
# Balance → Mean
# Age → Median
# Then
# Generate descriptive statistics.

df = pd.read_csv("C:\\Users\\bhoom\\Downloads\\Task_dataset.csv")
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
AnnualIncome_median = df['AnnualIncome'].median()
AnnualIncome_median

df['AnnualIncome'] = df['AnnualIncome'].fillna(AnnualIncome_median)
df['AnnualIncome'] = df['AnnualIncome'].astype("int")
df['AnnualIncome']
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0         49184      2139          581        NaN
# 1          10002  65.0        162964      6197          732    6356.54
# 2          10003  56.0         26956     37281          503  143203.92
# 3          10004  55.0         92926       925          463  139627.88
# 4          10005  66.0        108236      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0        173620      7121          644   60353.03
# 1016       10753  25.0         54490     13794          303  124512.07
# 1017       10810  49.0         82062     47170          813   53850.09
# 1018       10267  38.0        112358     10424          722  138100.05
# 1019       10059  62.0         97504     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
age_median = df['Age'].median()
age_median

df['Age'] = df['Age'].fillna(age_median)
df['Age'] = df['Age'].astype("int")
df['Age']
df
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0          10001   58         49184      2139          581        NaN       2
# 1          10002   65        162964      6197          732    6356.54       1
# 2          10003   56         26956     37281          503  143203.92       8
# 3          10004   55         92926       925          463  139627.88       5
# 4          10005   66        108236      7198          394   75985.46       5
# ...          ...  ...           ...       ...          ...        ...     ...
# 1015       10450   43        173620      7121          644   60353.03       2
# 1016       10753   25         54490     13794          303  124512.07       4
# 1017       10810   49         82062     47170          813   53850.09       8
# 1018       10267   38        112358     10424          722  138100.05       6
# 1019       10059   62         97504     36833          430        NaN      10
#
# ...

# %%
Balance_mean = df['AnnualIncome'].mean()
Balance_mean

df['Balance'] = df['Balance'].fillna(Balance_mean)
df['Balance'] = df['Balance'].astype("int")
df['Balance']
df
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore  Balance  Tenure  \
# 0          10001   58         49184      2139          581   112498       2
# 1          10002   65        162964      6197          732     6356       1
# 2          10003   56         26956     37281          503   143203       8
# 3          10004   55         92926       925          463   139627       5
# 4          10005   66        108236      7198          394    75985       5
# ...          ...  ...           ...       ...          ...      ...     ...
# 1015       10450   43        173620      7121          644    60353       2
# 1016       10753   25         54490     13794          303   124512       4
# 1017       10810   49         82062     47170          813    53850       8
# 1018       10267   38        112358     10424          722   138100       6
# 1019       10059   62         97504     36833          430   112498      10
#
#      Geography  Gender    Segment Target
# ...

# %%
df.describe()
# Out:
#          CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  1020.000000    1020.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112498.242157  25232.615686   602.659804
# std      288.022115    15.136428   50925.015723  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   69223.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  155570.750000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1020.000000  1020.000000
# mean    98271.791176     5.261765
# std     54480.295338     3.185330
# min       547.000000     0.000000
# 25%     52145.500000     2.000000
# 50%     99929.000000     5.000000
# 75%    142086.000000     8.000000
# ...

# %%
# Challenge 6 – Data Type Audit
# The company says
# Age and AnnualIncome are stored incorrectly.
# Tasks
# Convert
# Age → int
# AnnualIncome → float
# Balance → float
# Target → string
# Print information.

df['Age']=df['Age'].astype("int")
df['AnnualIncome']=df['AnnualIncome'].astype("float")
df['Balance']=df['Balance'].astype("float")
df['Target']=df['Target'].astype("str")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   int64
#  2   AnnualIncome  1020 non-null   float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       1020 non-null   float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 87.8+ KB

# %%
# Challenge 7 – Customer Analytics
# Create a new DataFrame that
# • removes Segment
# • removes Geography
# • removes duplicate rows
# Display
# • first 10 rows
# • dataset information
# • statistical summary

df
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore   Balance  Tenure  \
# 0          10001   58       49184.0      2139          581  112498.0       2
# 1          10002   65      162964.0      6197          732    6356.0       1
# 2          10003   56       26956.0     37281          503  143203.0       8
# 3          10004   55       92926.0       925          463  139627.0       5
# 4          10005   66      108236.0      7198          394   75985.0       5
# ...          ...  ...           ...       ...          ...       ...     ...
# 1015       10450   43      173620.0      7121          644   60353.0       2
# 1016       10753   25       54490.0     13794          303  124512.0       4
# 1017       10810   49       82062.0     47170          813   53850.0       8
# 1018       10267   38      112358.0     10424          722  138100.0       6
# 1019       10059   62       97504.0     36833          430  112498.0      10
#
#      Geography  Gender    Segment Target
# ...

# %%
df.drop('Segment', axis = 1)
df.drop('Geography',axis = 1)
df.drop_duplicates(inplace = True)
df
# Out:
#      CustomerID  Age  AnnualIncome  Spending  CreditScore   Balance  Tenure  \
# 0         10001   58       49184.0      2139          581  112498.0       2
# 1         10002   65      162964.0      6197          732    6356.0       1
# 2         10003   56       26956.0     37281          503  143203.0       8
# 3         10004   55       92926.0       925          463  139627.0       5
# 4         10005   66      108236.0      7198          394   75985.0       5
# ..          ...  ...           ...       ...          ...       ...     ...
# 995       10996   34       81731.0     40980          761  181465.0       5
# 996       10997   47       42475.0      1176          780   26640.0       5
# 997       10998   31      120531.0     46929          733  147220.0       4
# 998       10999   21       33661.0     22314          540   94186.0       5
# 999       11000   63       31930.0       851          559  100908.0       6
#
#     Geography  Gender    Segment Target
# ...

# %%
df.head(10)
# Out:
#    CustomerID  Age  AnnualIncome  Spending  CreditScore   Balance  Tenure  \
# 0       10001   58       49184.0      2139          581  112498.0       2
# 1       10002   65      162964.0      6197          732    6356.0       1
# 2       10003   56       26956.0     37281          503  143203.0       8
# 3       10004   55       92926.0       925          463  139627.0       5
# 4       10005   66      108236.0      7198          394   75985.0       5
# 5       10006   69       31390.0     48323          770  107245.0       6
# 6       10007   58      182141.0     24200          891   38457.0       1
# 7       10008   67       95861.0      5729          538  173296.0       6
# 8       10009   41       62638.0     24760          663   41901.0       4
# 9       10010   22      179680.0     42113          475  106827.0       3
#
#   Geography  Gender    Segment Target
# 0    France    Male        SME   Stay
# 1       USA    Male        SME  Churn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1000 non-null   int64
#  1   Age           1000 non-null   int64
#  2   AnnualIncome  1000 non-null   float64
#  3   Spending      1000 non-null   int64
#  4   CreditScore   1000 non-null   int64
#  5   Balance       1000 non-null   float64
#  6   Tenure        1000 non-null   int64
#  7   Geography     950 non-null    object
#  8   Gender        950 non-null    object
#  9   Segment       950 non-null    object
#  10  Target        1000 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 93.8+ KB

# %%
df.describe()
# Out:
#          CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1000.000000  1000.000000    1000.000000   1000.000000  1000.000000
# mean   10500.500000    44.202000  112453.288000  25285.558000   603.088000
# std      288.819436    15.130834   51081.479931  14211.735656   176.605486
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10250.750000    31.000000   68437.250000  13213.000000   441.000000
# 50%    10500.500000    44.000000  112358.000000  24901.000000   606.500000
# 75%    10750.250000    57.000000  155570.750000  37960.250000   758.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1000.000000  1000.000000
# mean    98304.117000     5.241000
# std     54527.473952     3.179155
# min       547.000000     0.000000
# 25%     52073.500000     2.000000
# 50%     99929.000000     5.000000
# 75%    142297.000000     8.000000
# ...

# %%
# Challenge 8 – ML Dataset Preparation
# Prepare a machine learning dataset.
# Perform
# • Remove duplicates
# • Remove CustomerID
# • Remove Segment
# • Fill missing values
# • Rename Target to Output
# Finally
# Display
# head()
# info()
# describe()
# value_counts(Output)

df.drop_duplicates(inplace=True)
df
# Out:
#      CustomerID  Age  AnnualIncome  Spending  CreditScore   Balance  Tenure  \
# 0         10001   58       49184.0      2139          581  112498.0       2
# 1         10002   65      162964.0      6197          732    6356.0       1
# 2         10003   56       26956.0     37281          503  143203.0       8
# 3         10004   55       92926.0       925          463  139627.0       5
# 4         10005   66      108236.0      7198          394   75985.0       5
# ..          ...  ...           ...       ...          ...       ...     ...
# 995       10996   34       81731.0     40980          761  181465.0       5
# 996       10997   47       42475.0      1176          780   26640.0       5
# 997       10998   31      120531.0     46929          733  147220.0       4
# 998       10999   21       33661.0     22314          540   94186.0       5
# 999       11000   63       31930.0       851          559  100908.0       6
#
#     Geography  Gender    Segment Target
# ...

# %%
df.drop('CustomerID', axis = 1 , inplace = True)
df.drop('Segment', axis = 1 , inplace = True)
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore   Balance  Tenure Geography  \
# 0     58       49184.0      2139          581  112498.0       2    France
# 1     65      162964.0      6197          732    6356.0       1       USA
# 2     56       26956.0     37281          503  143203.0       8    Canada
# 3     55       92926.0       925          463  139627.0       5       NaN
# 4     66      108236.0      7198          394   75985.0       5        UK
# ..   ...           ...       ...          ...       ...     ...       ...
# 995   34       81731.0     40980          761  181465.0       5   Germany
# 996   47       42475.0      1176          780   26640.0       5    France
# 997   31      120531.0     46929          733  147220.0       4     India
# 998   21       33661.0     22314          540   94186.0       5       NaN
# 999   63       31930.0       851          559  100908.0       6        UK
#
#      Gender Target
# 0      Male   Stay
# 1      Male  Churn
# ...

# %%
df.value_counts()
# Out:
# Age  AnnualIncome  Spending  CreditScore  Balance   Tenure  Geography  Gender  Target
# 18   21864.0       38378     835          23565.0   0       Canada     Other   Churn     1
# 50   123395.0      13243     802          63551.0   9       Germany    Male    Stay      1
# 52   88876.0       49456     898          85686.0   9       Canada     Female  Stay      1
#      102766.0      32391     607          50194.0   9       India      Female  Stay      1
#      106960.0      25655     443          158099.0  1       Germany    Other   Churn     1
#                                                                                         ..
# 37   28449.0       29973     569          69715.0   1       Canada     Male    Churn     1
#      29796.0       48393     890          76309.0   0       UK         Female  Churn     1
#      55947.0       25582     436          128315.0  10      USA        Male    Churn     1
# ...

# %%
df.rename(columns = {"Target":"Output"}, inplace = True)
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore   Balance  Tenure Geography  \
# 0     58       49184.0      2139          581  112498.0       2    France
# 1     65      162964.0      6197          732    6356.0       1       USA
# 2     56       26956.0     37281          503  143203.0       8    Canada
# 3     55       92926.0       925          463  139627.0       5       NaN
# 4     66      108236.0      7198          394   75985.0       5        UK
# ..   ...           ...       ...          ...       ...     ...       ...
# 995   34       81731.0     40980          761  181465.0       5   Germany
# 996   47       42475.0      1176          780   26640.0       5    France
# 997   31      120531.0     46929          733  147220.0       4     India
# 998   21       33661.0     22314          540   94186.0       5       NaN
# 999   63       31930.0       851          559  100908.0       6        UK
#
#      Gender Output
# 0      Male   Stay
# 1      Male  Churn
# ...

# %%
df.value_counts()
# Out:
# Age  AnnualIncome  Spending  CreditScore  Balance   Tenure  Geography  Gender  Output
# 18   21864.0       38378     835          23565.0   0       Canada     Other   Churn     1
# 50   123395.0      13243     802          63551.0   9       Germany    Male    Stay      1
# 52   88876.0       49456     898          85686.0   9       Canada     Female  Stay      1
#      102766.0      32391     607          50194.0   9       India      Female  Stay      1
#      106960.0      25655     443          158099.0  1       Germany    Other   Churn     1
#                                                                                         ..
# 37   28449.0       29973     569          69715.0   1       Canada     Male    Churn     1
#      29796.0       48393     890          76309.0   0       UK         Female  Churn     1
#      55947.0       25582     436          128315.0  10      USA        Male    Churn     1
# ...

# %%
# Challenge 9 – Column Transformation
# Create these new columns
# NetWorth = Balance + AnnualIncome
# AgeAfterRetirement = Age + 20
# DoubleCreditScore = CreditScore * 2
# IncomePerMonth = AnnualIncome / 12
# Then
# Display first 15 rows.

df
# Out:
#      Age  AnnualIncome  Spending  CreditScore   Balance  Tenure Geography  \
# 0     58       49184.0      2139          581  112498.0       2    France
# 1     65      162964.0      6197          732    6356.0       1       USA
# 2     56       26956.0     37281          503  143203.0       8    Canada
# 3     55       92926.0       925          463  139627.0       5       NaN
# 4     66      108236.0      7198          394   75985.0       5        UK
# ..   ...           ...       ...          ...       ...     ...       ...
# 995   34       81731.0     40980          761  181465.0       5   Germany
# 996   47       42475.0      1176          780   26640.0       5    France
# 997   31      120531.0     46929          733  147220.0       4     India
# 998   21       33661.0     22314          540   94186.0       5       NaN
# 999   63       31930.0       851          559  100908.0       6        UK
#
#      Gender Output
# 0      Male   Stay
# 1      Male  Churn
# ...

# %%
df["NetWorth"]=df["Balance"]+df["AnnualIncome"]
df["AgeAfterRetirement"]= df["Age"] + 20
df["DoubleCreditScore"]=df["CreditScore"]*2
df["IncomePerMonth"]=df["AnnualIncome"]/12
df.head(15)
# Out:
#     Age  AnnualIncome  Spending  CreditScore   Balance  Tenure Geography  \
# 0    58       49184.0      2139          581  112498.0       2    France
# 1    65      162964.0      6197          732    6356.0       1       USA
# 2    56       26956.0     37281          503  143203.0       8    Canada
# 3    55       92926.0       925          463  139627.0       5       NaN
# 4    66      108236.0      7198          394   75985.0       5        UK
# 5    69       31390.0     48323          770  107245.0       6     India
# 6    58      182141.0     24200          891   38457.0       1     India
# 7    67       95861.0      5729          538  173296.0       6        UK
# 8    41       62638.0     24760          663   41901.0       4    France
# 9    22      179680.0     42113          475  106827.0       3       USA
# 10   44      187772.0     45599          870   43923.0       5     India
# 11   69      102694.0     26790          574   13237.0       9    France
# ...

# %%
# Challenge 10 – Company Report
# Display
# • first five rows
# • last five rows
# • ten random rows
# • dataset information
# • descriptive statistics
# Finally rename
# Target → Customer_Status

df.head()
# Out:
#    Age  AnnualIncome  Spending  CreditScore   Balance  Tenure Geography  \
# 0   58       49184.0      2139          581  112498.0       2    France
# 1   65      162964.0      6197          732    6356.0       1       USA
# 2   56       26956.0     37281          503  143203.0       8    Canada
# 3   55       92926.0       925          463  139627.0       5       NaN
# 4   66      108236.0      7198          394   75985.0       5        UK
#
#   Gender Output  NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# 0   Male   Stay  161682.0                  78               1162
# 1   Male  Churn  169320.0                  85               1464
# 2   Male   Stay  170159.0                  76               1006
# 3   Male  Churn  232553.0                  75                926
# 4  Other  Churn  184221.0                  86                788
#
#    IncomePerMonth
# 0     4098.666667
# 1    13580.333333
# 2     2246.333333
# 3     7743.833333
# 4     9019.666667

# %%
df.tail()
# Out:
#      Age  AnnualIncome  Spending  CreditScore   Balance  Tenure Geography  \
# 995   34       81731.0     40980          761  181465.0       5   Germany
# 996   47       42475.0      1176          780   26640.0       5    France
# 997   31      120531.0     46929          733  147220.0       4     India
# 998   21       33661.0     22314          540   94186.0       5       NaN
# 999   63       31930.0       851          559  100908.0       6        UK
#
#      Gender Output  NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# 995   Other   Stay  263196.0                  54               1522
# 996  Female   Stay   69115.0                  67               1560
# 997    Male   Stay  267751.0                  51               1466
# 998   Other   Stay  127847.0                  41               1080
# 999  Female   Stay  132838.0                  83               1118
#
#      IncomePerMonth
# 995     6810.916667
# 996     3539.583333
# 997    10044.250000
# 998     2805.083333
# ...

# %%
df.sample(10)
# Out:
#      Age  AnnualIncome  Spending  CreditScore   Balance  Tenure Geography  \
# 75    39      195341.0     45008          714  144836.0       7       USA
# 701   56       24273.0     34422          438  198682.0       4     India
# 132   27       84014.0     35310          721  113185.0       2       USA
# 544   55       65521.0     48373          431   20710.0      10   Germany
# 629   67      140284.0     45168          771  179304.0       0    Canada
# 472   27      175988.0     17400          627  182160.0       1     India
# 123   46      112358.0     32241          653  112498.0       8    Canada
# 307   68      157484.0     21388          726   81651.0       4    Canada
# 322   27       22396.0     14834          817   91201.0       0   Germany
# 356   24       87826.0     15049          822  149370.0       8   Germany
#
#      Gender Output  NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# 75    Other   Stay  340177.0                  59               1428
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1000 non-null   int64
#  1   AnnualIncome        1000 non-null   float64
#  2   Spending            1000 non-null   int64
#  3   CreditScore         1000 non-null   int64
#  4   Balance             1000 non-null   float64
#  5   Tenure              1000 non-null   int64
#  6   Geography           950 non-null    object
#  7   Gender              950 non-null    object
#  8   Output              1000 non-null   object
#  9   NetWorth            1000 non-null   float64
#  10  AgeAfterRetirement  1000 non-null   int64
#  11  DoubleCreditScore   1000 non-null   int64
#  12  IncomePerMonth      1000 non-null   float64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 109.4+ KB

# %%
df.describe()
# Out:
#                Age   AnnualIncome      Spending  CreditScore        Balance  \
# count  1000.000000    1000.000000   1000.000000  1000.000000    1000.000000
# mean     44.202000  112453.288000  25285.558000   603.088000   98304.117000
# std      15.130834   51081.479931  14211.735656   176.605486   54527.473952
# min      18.000000   20227.000000    537.000000   300.000000     547.000000
# 25%      31.000000   68437.250000  13213.000000   441.000000   52073.500000
# 50%      44.000000  112358.000000  24901.000000   606.500000   99929.000000
# 75%      57.000000  155570.750000  37960.250000   758.250000  142297.000000
# max      70.000000  199967.000000  49995.000000   900.000000  199885.000000
#
#             Tenure       NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# count  1000.000000    1000.000000         1000.000000        1000.000000
# mean      5.241000  210757.405000           64.202000        1206.176000
# ...

# %%
df.rename(columns = {"Output":"Customer_Status"},inplace = True)
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore   Balance  Tenure Geography  \
# 0     58       49184.0      2139          581  112498.0       2    France
# 1     65      162964.0      6197          732    6356.0       1       USA
# 2     56       26956.0     37281          503  143203.0       8    Canada
# 3     55       92926.0       925          463  139627.0       5       NaN
# 4     66      108236.0      7198          394   75985.0       5        UK
# ..   ...           ...       ...          ...       ...     ...       ...
# 995   34       81731.0     40980          761  181465.0       5   Germany
# 996   47       42475.0      1176          780   26640.0       5    France
# 997   31      120531.0     46929          733  147220.0       4     India
# 998   21       33661.0     22314          540   94186.0       5       NaN
# 999   63       31930.0       851          559  100908.0       6        UK
#
#      Gender Customer_Status  NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# ...

# %%
# Challenge 11 – Missing Value Report
# Create a report showing
# • Total missing values
# • Numerical columns
# • Mean of Balance
# • Median of Age
# • Fill missing values
# • Display information again

df.describe()
# Out:
#                Age   AnnualIncome      Spending  CreditScore        Balance  \
# count  1000.000000    1000.000000   1000.000000  1000.000000    1000.000000
# mean     44.202000  112453.288000  25285.558000   603.088000   98304.117000
# std      15.130834   51081.479931  14211.735656   176.605486   54527.473952
# min      18.000000   20227.000000    537.000000   300.000000     547.000000
# 25%      31.000000   68437.250000  13213.000000   441.000000   52073.500000
# 50%      44.000000  112358.000000  24901.000000   606.500000   99929.000000
# 75%      57.000000  155570.750000  37960.250000   758.250000  142297.000000
# max      70.000000  199967.000000  49995.000000   900.000000  199885.000000
#
#             Tenure       NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# count  1000.000000    1000.000000         1000.000000        1000.000000
# mean      5.241000  210757.405000           64.202000        1206.176000
# ...

# %%
Age_median = df['Age'].median()
Age_median

df['Age'] = df['Age'].fillna(Age_median)
df['Age'] = df['Age'].astype("int")
df['Age']

Balance_median = df['Balance'].median()
Balance_median

df['Balance'] = df['Balance'].fillna(Balance_median)
df['Balance'] = df['Balance'].astype("int")
df['Balance']
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore  Balance  Tenure Geography  \
# 0     58       49184.0      2139          581   112498       2    France
# 1     65      162964.0      6197          732     6356       1       USA
# 2     56       26956.0     37281          503   143203       8    Canada
# 3     55       92926.0       925          463   139627       5       NaN
# 4     66      108236.0      7198          394    75985       5        UK
# ..   ...           ...       ...          ...      ...     ...       ...
# 995   34       81731.0     40980          761   181465       5   Germany
# 996   47       42475.0      1176          780    26640       5    France
# 997   31      120531.0     46929          733   147220       4     India
# 998   21       33661.0     22314          540    94186       5       NaN
# 999   63       31930.0       851          559   100908       6        UK
#
#      Gender Customer_Status  NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1000 non-null   int64
#  1   AnnualIncome        1000 non-null   float64
#  2   Spending            1000 non-null   int64
#  3   CreditScore         1000 non-null   int64
#  4   Balance             1000 non-null   int64
#  5   Tenure              1000 non-null   int64
#  6   Geography           950 non-null    object
#  7   Gender              950 non-null    object
#  8   Customer_Status     1000 non-null   object
#  9   NetWorth            1000 non-null   float64
#  10  AgeAfterRetirement  1000 non-null   int64
#  11  DoubleCreditScore   1000 non-null   int64
#  12  IncomePerMonth      1000 non-null   float64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 109.4+ KB

# %%
# Challenge 12 – Customer Classification
# Count
# Stay
# Churn
# Then
# Rename
# Target → Customer_Class
# Convert it into string.

df.value_counts("Customer_Status")
# Out:
# Customer_Status
# Churn    506
# Stay     494
# Name: count, dtype: int64

# %%
df.rename(columns = {"Customer_Status":"Customer_Class"}, inplace = True)
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore  Balance  Tenure Geography  \
# 0     58       49184.0      2139          581   112498       2    France
# 1     65      162964.0      6197          732     6356       1       USA
# 2     56       26956.0     37281          503   143203       8    Canada
# 3     55       92926.0       925          463   139627       5       NaN
# 4     66      108236.0      7198          394    75985       5        UK
# ..   ...           ...       ...          ...      ...     ...       ...
# 995   34       81731.0     40980          761   181465       5   Germany
# 996   47       42475.0      1176          780    26640       5    France
# 997   31      120531.0     46929          733   147220       4     India
# 998   21       33661.0     22314          540    94186       5       NaN
# 999   63       31930.0       851          559   100908       6        UK
#
#      Gender Customer_Class  NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# ...

# %%
df['Customer_Class'] = df['Customer_Class'].astype("str")
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore  Balance  Tenure Geography  \
# 0     58       49184.0      2139          581   112498       2    France
# 1     65      162964.0      6197          732     6356       1       USA
# 2     56       26956.0     37281          503   143203       8    Canada
# 3     55       92926.0       925          463   139627       5       NaN
# 4     66      108236.0      7198          394    75985       5        UK
# ..   ...           ...       ...          ...      ...     ...       ...
# 995   34       81731.0     40980          761   181465       5   Germany
# 996   47       42475.0      1176          780    26640       5    France
# 997   31      120531.0     46929          733   147220       4     India
# 998   21       33661.0     22314          540    94186       5       NaN
# 999   63       31930.0       851          559   100908       6        UK
#
#      Gender Customer_Class  NetWorth  AgeAfterRetirement  DoubleCreditScore  \
# ...

# %%
# Challenge 13 – Sales Department
# Rename
# Balance → AccountBalance
# AnnualIncome → Salary
# CreditScore → Score
# Add prefix
# Sales_
# Then
# Display
# sample(20)

df.rename(columns={"Balance":"AccountBalance",
                   "AnnualIncome":"Salary",
                   "CreditScore":"Score"},inplace = True)
df.add_prefix("Sales_")
df.sample(20)
# Out:
#      Age    Salary  Spending  Score  AccountBalance  Tenure Geography  Gender  \
# 447   69   54207.0     22831    481          183756       5     India    Male
# 30    46  164264.0      6916    351          130428       8     India    Male
# 33    27   69780.0     19945    522          193741       9    France   Other
# 737   48  190280.0     25007    488          170425       7    Canada    Male
# 834   42  107203.0      4436    564          191121       4       USA  Female
# 736   44   26837.0     24044    381          137628       7       USA   Other
# 755   53   74430.0      3705    489           29651      10        UK    Male
# 526   55  112358.0     37786    748          112498       6        UK   Other
# 965   70  142498.0     18059    845          161786       6   Germany   Other
# 692   47  187488.0      4478    669          111603       6        UK   Other
# 273   34  145587.0     14523    506          165590       4   Germany   Other
# ...

# %%
# Challenge 14 – Interview Challenge
# Without creating another DataFrame,
# perform
# • remove duplicates
# • rename Target
# • fill missing values
# • convert Balance to float
# • display summary

df.drop_duplicates()
# Out:
#      Age    Salary  Spending  Score  AccountBalance  Tenure Geography  Gender  \
# 0     58   49184.0      2139    581          112498       2    France    Male
# 1     65  162964.0      6197    732            6356       1       USA    Male
# 2     56   26956.0     37281    503          143203       8    Canada    Male
# 3     55   92926.0       925    463          139627       5       NaN    Male
# 4     66  108236.0      7198    394           75985       5        UK   Other
# ..   ...       ...       ...    ...             ...     ...       ...     ...
# 995   34   81731.0     40980    761          181465       5   Germany   Other
# 996   47   42475.0      1176    780           26640       5    France  Female
# 997   31  120531.0     46929    733          147220       4     India    Male
# 998   21   33661.0     22314    540           94186       5       NaN   Other
# 999   63   31930.0       851    559          100908       6        UK  Female
#
# ...

# %%
df['AccountBalance'] = df['AccountBalance'].astype("float")
df
# Out:
#      Age    Salary  Spending  Score  AccountBalance  Tenure Geography  Gender  \
# 0     58   49184.0      2139    581        112498.0       2    France    Male
# 1     65  162964.0      6197    732          6356.0       1       USA    Male
# 2     56   26956.0     37281    503        143203.0       8    Canada    Male
# 3     55   92926.0       925    463        139627.0       5       NaN    Male
# 4     66  108236.0      7198    394         75985.0       5        UK   Other
# ..   ...       ...       ...    ...             ...     ...       ...     ...
# 995   34   81731.0     40980    761        181465.0       5   Germany   Other
# 996   47   42475.0      1176    780         26640.0       5    France  Female
# 997   31  120531.0     46929    733        147220.0       4     India    Male
# 998   21   33661.0     22314    540         94186.0       5       NaN   Other
# 999   63   31930.0       851    559        100908.0       6        UK  Female
#
# ...

# %%
# Challenge 15 – Data Engineer Task
# Load the dataset.
# Create another DataFrame containing only numeric columns.
# Drop
# CustomerID
# Target
# Display summary.

df = pd.read_csv("C:\\Users\\bhoom\\Downloads\\Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df1=df.describe()
df1
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# ...

# %%
df.drop("CustomerID",axis = 1)
df.drop("Target",axis = 1)
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# ...

# %%
# Challenge 16 – Mixed Cleaning
# Perform
# drop_duplicates()
# fillna()
# astype()
# rename()
# head()
# info()
# using only one DataFrame variable.

df.drop_duplicates()
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
# ..          ...   ...           ...       ...          ...        ...     ...
# 995       10996  34.0       81731.0     40980          761  181465.65       5
# 996       10997  47.0       42475.0      1176          780   26640.99       5
# 997       10998  31.0      120531.0     46929          733  147220.82       4
# 998       10999  21.0       33661.0     22314          540   94186.48       5
# 999       11000  63.0       31930.0       851          559  100908.40       6
#
# ...

# %%
Age_median = df['Age'].median()
Age_median

df['Age'] = df['Age'].fillna(Age_median)
df['Age'] = df['Age'].astype("int")
df['Age']
# Out:
# 0       58
# 1       65
# 2       56
# 3       55
# 4       66
#         ..
# 1015    43
# 1016    25
# 1017    49
# 1018    38
# 1019    62
# Name: Age, Length: 1020, dtype: int64

# %%
df.head()
# Out:
#    CustomerID  Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001   58       49184.0      2139          581        NaN       2
# 1       10002   65      162964.0      6197          732    6356.54       1
# 2       10003   56       26956.0     37281          503  143203.92       8
# 3       10004   55       92926.0       925          463  139627.88       5
# 4       10005   66      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   int64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 87.8+ KB

# %%
# Challenge 17 – Real Company Dataset
# Manager asks
# Remove duplicate records
# Fill missing values
# Rename all business columns
# Add company prefix
# Display summary
# Display target counts


df.rename(columns={
    "Surname": "CustomerName",
    "Geography": "Country",
    "Gender": "CustomerGender",
    "Exited": "Target"},inplace = True)

df.add_prefix("Em_")
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# ...

# %%
df.value_counts("Target")
# Out:
# Target
# Churn    515
# Stay     505
# Name: count, dtype: int64

# %%
# Challenge 18 – Customer Summary
# Generate
# Mean Balance
# Median Balance
# Mean Age
# Median AnnualIncome
# Then
# fill missing values using these statistics.

mean_balance = df["Balance"].mean()
median_balance = df["Balance"].median()

mean_age = df["Age"].mean()

median_income = df["AnnualIncome"].median()

print("Mean Balance:", mean_balance)
print("Median Balance:", median_balance)
print("Mean Age:", mean_age)
print("Median AnnualIncome:", median_income)
# Out:
# Mean Balance: 97523.53566563467
# Median Balance: 95100.06
# Mean Age: 44.24948453608248
# Median AnnualIncome: 112358.0

# %%
df["Balance"] = df["Balance"].fillna(mean_balance)
df["Age"] = df["Age"].fillna(mean_age)
df["AnnualIncome"] = df["AnnualIncome"].fillna(median_income)
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0          10001  58.0       49184.0      2139          581   97523.535666
# 1          10002  65.0      162964.0      6197          732    6356.540000
# 2          10003  56.0       26956.0     37281          503  143203.920000
# 3          10004  55.0       92926.0       925          463  139627.880000
# 4          10005  66.0      108236.0      7198          394   75985.460000
# ...          ...   ...           ...       ...          ...            ...
# 1015       10450  43.0      173620.0      7121          644   60353.030000
# 1016       10753  25.0       54490.0     13794          303  124512.070000
# 1017       10810  49.0       82062.0     47170          813   53850.090000
# 1018       10267  38.0      112358.0     10424          722  138100.050000
# 1019       10059  62.0       97504.0     36833          430   97523.535666
#
#       Tenure  Country CustomerGender    Segment Target
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID         0
# Age                0
# AnnualIncome       0
# Spending           0
# CreditScore        0
# Balance            0
# Tenure             0
# Country           51
# CustomerGender    52
# Segment           51
# Target             0
# dtype: int64

# %%
# Challenge 19 – Transformation Challenge
# Create
# Income_in_Lakhs
# Balance_in_Lakhs
# SeniorCitizen
# HighCreditScore
# where
# SeniorCitizen = Age + 0
# HighCreditScore = CreditScore * 1
# (No conditional statements.)

df["Income_in_Lakhs"] = df["AnnualIncome"] / 100000
df["Balance_in_Lakhs"] = df["Balance"] / 100000
df["SeniorCitizen"] = df["Age"] + 0
df["HighCreditScore"] = df["CreditScore"] * 1
df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001  58.0       49184.0      2139          581   97523.535666
# 1       10002  65.0      162964.0      6197          732    6356.540000
# 2       10003  56.0       26956.0     37281          503  143203.920000
# 3       10004  55.0       92926.0       925          463  139627.880000
# 4       10005  66.0      108236.0      7198          394   75985.460000
#
#    Tenure Country CustomerGender    Segment Target  Income_in_Lakhs  \
# 0       2  France           Male        SME   Stay          0.49184
# 1       1     USA           Male        SME  Churn          1.62964
# 2       8  Canada           Male  Corporate   Stay          0.26956
# 3       5     NaN           Male     Retail  Churn          0.92926
# 4       5      UK          Other  Corporate  Churn          1.08236
#
#    Balance_in_Lakhs  SeniorCitizen  HighCreditScore
# 0          0.975235           58.0              581
# ...

# %% [markdown]
# # Challenge 20 – Final Interview Project
# Your manager gives you a dirty customer dataset.
# Prepare the final dataset.
# Requirements
# Load dataset
# Check information
# Find missing values
# Remove duplicates
# Rename
# CustomerID
# AnnualIncome
# CreditScore
# Target
#
# Convert
# Age
#
# Sumit Sir Notes
# AnnualIncome
# Balance
#
# Fill missing values
# Remove
# Segment
# CustomerID
# Create new columns
# TotalMoney = Balance + AnnualIncome
# AgeAfter5Years = Age + 5
# MonthlyIncome = AnnualIncome / 12
# CreditScoreDouble = CreditScore * 2Display
# • Head
# • Tail
# • Sample
# • Describe
# • Target counts
# • Final information

# %%
df = df.drop_duplicates()

df = df.rename(columns={
    "CustomerId": "CustomerID",
    "EstimatedSalary": "AnnualIncome",
    "Exited": "Target"})
df
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0         10001  58.0       49184.0      2139          581   97523.535666
# 1         10002  65.0      162964.0      6197          732    6356.540000
# 2         10003  56.0       26956.0     37281          503  143203.920000
# 3         10004  55.0       92926.0       925          463  139627.880000
# 4         10005  66.0      108236.0      7198          394   75985.460000
# ..          ...   ...           ...       ...          ...            ...
# 995       10996  34.0       81731.0     40980          761  181465.650000
# 996       10997  47.0       42475.0      1176          780   26640.990000
# 997       10998  31.0      120531.0     46929          733  147220.820000
# 998       10999  21.0       33661.0     22314          540   94186.480000
# 999       11000  63.0       31930.0       851          559  100908.400000
#
#      Tenure  Country CustomerGender    Segment Target  Income_in_Lakhs  \
# ...

# %%
df["Age"] = df["Age"].astype(int)
df["AnnualIncome"] = df["AnnualIncome"].astype(float)
df["Balance"] = df["Balance"].astype(float)
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore        Balance  Tenure  Country  \
# 0     58       49184.0      2139          581   97523.535666       2   France
# 1     65      162964.0      6197          732    6356.540000       1      USA
# 2     56       26956.0     37281          503  143203.920000       8   Canada
# 3     55       92926.0       925          463  139627.880000       5      NaN
# 4     66      108236.0      7198          394   75985.460000       5       UK
# ..   ...           ...       ...          ...            ...     ...      ...
# 995   34       81731.0     40980          761  181465.650000       5  Germany
# 996   47       42475.0      1176          780   26640.990000       5   France
# 997   31      120531.0     46929          733  147220.820000       4    India
# 998   21       33661.0     22314          540   94186.480000       5      NaN
# 999   63       31930.0       851          559  100908.400000       6       UK
#
# ...

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["AnnualIncome"] = df["AnnualIncome"].fillna(df["AnnualIncome"].mean())
df["Balance"] = df["Balance"].fillna(df["Balance"].mean())
df["CreditScore"] = df["CreditScore"].fillna(df["CreditScore"].mean())
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore        Balance  Tenure  Country  \
# 0     58       49184.0      2139          581   97523.535666       2   France
# 1     65      162964.0      6197          732    6356.540000       1      USA
# 2     56       26956.0     37281          503  143203.920000       8   Canada
# 3     55       92926.0       925          463  139627.880000       5      NaN
# 4     66      108236.0      7198          394   75985.460000       5       UK
# ..   ...           ...       ...          ...            ...     ...      ...
# 995   34       81731.0     40980          761  181465.650000       5  Germany
# 996   47       42475.0      1176          780   26640.990000       5   France
# 997   31      120531.0     46929          733  147220.820000       4    India
# 998   21       33661.0     22314          540   94186.480000       5      NaN
# 999   63       31930.0       851          559  100908.400000       6       UK
#
# ...

# %%
df = df.drop(columns=["Segment", "CustomerID"], errors="ignore")
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore        Balance  Tenure  Country  \
# 0     58       49184.0      2139          581   97523.535666       2   France
# 1     65      162964.0      6197          732    6356.540000       1      USA
# 2     56       26956.0     37281          503  143203.920000       8   Canada
# 3     55       92926.0       925          463  139627.880000       5      NaN
# 4     66      108236.0      7198          394   75985.460000       5       UK
# ..   ...           ...       ...          ...            ...     ...      ...
# 995   34       81731.0     40980          761  181465.650000       5  Germany
# 996   47       42475.0      1176          780   26640.990000       5   France
# 997   31      120531.0     46929          733  147220.820000       4    India
# 998   21       33661.0     22314          540   94186.480000       5      NaN
# 999   63       31930.0       851          559  100908.400000       6       UK
#
# ...

# %%
df["TotalMoney"] = df["Balance"] + df["AnnualIncome"]
df["AgeAfter5Years"] = df["Age"] + 5
df["MonthlyIncome"] = df["AnnualIncome"] / 12
df["CreditScoreDouble"] = df["CreditScore"] * 2
df
# Out:
#      Age  AnnualIncome  Spending  CreditScore        Balance  Tenure  Country  \
# 0     58       49184.0      2139          581   97523.535666       2   France
# 1     65      162964.0      6197          732    6356.540000       1      USA
# 2     56       26956.0     37281          503  143203.920000       8   Canada
# 3     55       92926.0       925          463  139627.880000       5      NaN
# 4     66      108236.0      7198          394   75985.460000       5       UK
# ..   ...           ...       ...          ...            ...     ...      ...
# 995   34       81731.0     40980          761  181465.650000       5  Germany
# 996   47       42475.0      1176          780   26640.990000       5   France
# 997   31      120531.0     46929          733  147220.820000       4    India
# 998   21       33661.0     22314          540   94186.480000       5      NaN
# 999   63       31930.0       851          559  100908.400000       6       UK
#
# ...

# %%
df.head()
# Out:
#    Age  AnnualIncome  Spending  CreditScore        Balance  Tenure Country  \
# 0   58       49184.0      2139          581   97523.535666       2  France
# 1   65      162964.0      6197          732    6356.540000       1     USA
# 2   56       26956.0     37281          503  143203.920000       8  Canada
# 3   55       92926.0       925          463  139627.880000       5     NaN
# 4   66      108236.0      7198          394   75985.460000       5      UK
#
#   CustomerGender Target  Income_in_Lakhs  Balance_in_Lakhs  SeniorCitizen  \
# 0           Male   Stay          0.49184          0.975235           58.0
# 1           Male  Churn          1.62964          0.063565           65.0
# 2           Male   Stay          0.26956          1.432039           56.0
# 3           Male  Churn          0.92926          1.396279           55.0
# 4          Other  Churn          1.08236          0.759855           66.0
#
#    HighCreditScore     TotalMoney  AgeAfter5Years  MonthlyIncome  \
# ...

# %%
df.tail()
# Out:
#      Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  Country  \
# 995   34       81731.0     40980          761  181465.65       5  Germany
# 996   47       42475.0      1176          780   26640.99       5   France
# 997   31      120531.0     46929          733  147220.82       4    India
# 998   21       33661.0     22314          540   94186.48       5      NaN
# 999   63       31930.0       851          559  100908.40       6       UK
#
#     CustomerGender Target  Income_in_Lakhs  Balance_in_Lakhs  SeniorCitizen  \
# 995          Other   Stay          0.81731          1.814656           34.0
# 996         Female   Stay          0.42475          0.266410           47.0
# 997           Male   Stay          1.20531          1.472208           31.0
# 998          Other   Stay          0.33661          0.941865           21.0
# 999         Female   Stay          0.31930          1.009084           63.0
#
# ...

# %%
df.sample(5)
# Out:
#      Age  AnnualIncome  Spending  CreditScore        Balance  Tenure  Country  \
# 624   60      123584.0     27071          900   40062.080000       0   France
# 961   44      171569.0      6708          644   54672.990000       9  Germany
# 986   30      184704.0     20524          621  115161.870000       1      USA
# 465   23      188261.0     36159          696   97523.535666       6       UK
# 265   27      112358.0     16372          332  114514.050000       1      USA
#
#     CustomerGender Target  Income_in_Lakhs  Balance_in_Lakhs  SeniorCitizen  \
# 624          Other  Churn          1.23584          0.400621      60.000000
# 961         Female   Stay          1.71569          0.546730      44.249485
# 986           Male  Churn          1.84704          1.151619      30.000000
# 465           Male   Stay          1.88261          0.975235      23.000000
# 265           Male  Churn          1.12358          1.145141      27.000000
#
# ...

# %%
df.describe(include="all")
# Out:
#                 Age   AnnualIncome      Spending  CreditScore        Balance  \
# count   1000.000000    1000.000000   1000.000000  1000.000000    1000.000000
# unique          NaN            NaN           NaN          NaN            NaN
# top             NaN            NaN           NaN          NaN            NaN
# freq            NaN            NaN           NaN          NaN            NaN
# mean      44.202000  112453.288000  25285.558000   603.088000   97555.864273
# std       15.130834   51081.479931  14211.735656   176.605486   54430.062511
# min       18.000000   20227.000000    537.000000   300.000000     547.600000
# 25%       31.000000   68437.250000  13213.000000   441.000000   52074.240000
# 50%       44.000000  112358.000000  24901.000000   606.500000   97523.535666
# 75%       57.000000  155570.750000  37960.250000   758.250000  142297.910000
# max       70.000000  199967.000000  49995.000000   900.000000  199885.880000
#
# ...

# %%
df["Target"].value_counts()
# Out:
# Target
# Churn    506
# Stay     494
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                1000 non-null   int64
#  1   AnnualIncome       1000 non-null   float64
#  2   Spending           1000 non-null   int64
#  3   CreditScore        1000 non-null   int64
#  4   Balance            1000 non-null   float64
#  5   Tenure             1000 non-null   int64
#  6   Country            950 non-null    object
#  7   CustomerGender     950 non-null    object
#  8   Target             1000 non-null   object
#  9   Income_in_Lakhs    1000 non-null   float64
#  10  Balance_in_Lakhs   1000 non-null   float64
#  11  SeniorCitizen      1000 non-null   float64
#  12  HighCreditScore    1000 non-null   int64
#  13  TotalMoney         1000 non-null   float64
#  14  AgeAfter5Years     1000 non-null   int64
#  15  MonthlyIncome      1000 non-null   float64
# ...
