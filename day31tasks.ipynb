# %%
# Q1. Load the dataset
# Load messy_customer_analytics_2000x15.csv into a DataFrame called df.
# Then display the first 10 rows.
# Use: pd.read_csv(), head()

import pandas as pd
df = pd.read_csv("C:\\Users\\bhoom\\Downloads\\customer_analytics - customer_analytics.csv")
df.head()
# Out:
#    Customer_ID Age Annual_Income Account_Balance Credit_Score  Tenure_Years  \
# 0       101317  55         44033       111350.85          772             3
# 1       101001  32        215546       254378.37          374             8
# 2       101069  23        226403       159975.42          668            12
# 3       101968  66         87824        295741.6          315            14
# 4       100530  67         31570       242423.78          370             4
#
#         City  Segment Channel            Join_Date Active Risk_Level  \
# 0  Bangalore      SME   Agent  2022-08-15 00:00:00    Yes        Low
# 1      Delhi   Retail   Agent  2025-01-11 00:00:00    Yes       High
# 2    Chennai  Premium   Agent  2024-08-01 00:00:00     No     Medium
# 3     Mumbai  Premium   Agent  2021-05-15 00:00:00    Yes       High
# 4  bangalore   Retail   Agent  2026-02-03 00:00:00     No       High
#
#   Monthly_Spend Transactions  Satisfaction_Score
# 0      23066.19          135                 3.1
# 1           NaN          106                 8.2
# 2      28536.34          146                 6.3
# 3      12869.71          115                 9.7
# 4      34163.02           94                 3.7

# %%
# Q2. Inspect the end of the dataset
# Display the last 15 rows.
# Use: tail()

df.tail(15)
# Out:
#       Customer_ID            Age Annual_Income Account_Balance Credit_Score  \
# 2025       100088             51        214004       173779.91          686
# 2026       101483  not_available        117573       261905.82          657
# 2027       100331             54        123511       280896.35          388
# 2028       101239             31        125500       189174.28          846
# 2029       100467            NaN        101619       279182.04          392
# 2030       100122             41        201611        40736.71          507
# 2031       101639             61        128850        266135.8          840
# 2032       101045             33         88037       129948.93          449
# 2033       101725             43        122756        36633.45          487
# 2034       101096             18        189232       235131.72          306
# 2035       101131             42         88530       153490.72          677
# 2036       101295             31        205738        270989.4          392
# 2037       100861             25        211994       160507.65          737
# 2038       101460             64         30105        32117.15          794
# 2039       101127             55        248332       274980.99          783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 2025             6       Pune    Premium  Branch  2022-04-22 00:00:00    Yes
# 2026             2       Pune        NaN  Branch  2022-07-02 00:00:00    Yes
# 2027             5       Pune    Premium  Mobile  2024-09-11 00:00:00     No
# 2028            11      Delhi  Corporate   Agent  2022-04-08 00:00:00    Yes
# 2029             3  Bangalore     Retail  Mobile  2023-07-26 00:00:00    Yes
# 2030            15  Bangalore        SME   Agent  2024-11-03 00:00:00    Yes
# 2031             9    Kolkata        SME  Mobile  2026-01-15 00:00:00    Yes
# 2032             8     Mumbai    Premium  Mobile  2022-11-30 00:00:00    Yes
# 2033             8       Pune        NaN  Mobile  2021-07-04 00:00:00     No
# 2034            10  hyderabad        SME  Mobile  2025-09-10 00:00:00     No
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level  Monthly_Spend Transactions  Satisfaction_Score
# 2025     Medium       39764.87           85                 4.9
# 2026     Medium       39559.16            7                 1.9
# 2027       High            NaN           48                 6.7
# 2028        Low       22161.09          102                 8.5
# 2029       High       37316.48          100                 7.3
# 2030       High       18815.18           58                 7.2
# 2031        Low       34300.44           83                 5.0
# 2032       High  not_available          147                 9.7
# 2033       High       10165.71           14                 6.4
# 2034       High       27227.44           85                 5.9
# 2035     Medium        8455.42          119                 8.6
# 2036       High       34087.69          134                 2.6
# 2037        Low       26518.74           87                 1.3
# 2038        Low       20943.11          107                 9.3
# 2039        Low       48511.32          119                 3.1

# %%
# Q3. Random inspection
# Display 10 random records.
# Use: sample()

df.sample(10)
# Out:
#       Customer_ID Age Annual_Income Account_Balance Credit_Score  \
# 1423       101958  70        187331             NaN          501
# 864        100979  47         60262       209182.63          786
# 1150       101579  64        233015             NaN          338
# 1114       101164  36         64279       193277.02          667
# 1391       100279  69         99441       174977.25          586
# 828        101855  62        215747        86475.47          375
# 1915       100380  20        136822       173752.58          630
# 139        100465  46        227332       206999.92          656
# 1570       100538  75         57556          132.83          793
# 732        100222  23           NaN       220208.93          639
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 1423            11      Delhi     Retail   Agent  2023-10-02 00:00:00    Yes
# 864              4       Pune    Premium   Agent  2022-05-22 00:00:00    Yes
# 1150            12  Bangalore    Premium  Online  2024-06-18 00:00:00    Yes
# 1114            13  Hyderabad        SME  Online  2024-11-14 00:00:00    Yes
# 1391             6    Chennai  Corporate  Online  2023-03-29 00:00:00    NaN
# 828             14    Chennai    Premium   Agent  2026-01-21 00:00:00     No
# 1915             7       Pune  Corporate  Branch  2022-04-30 00:00:00     no
# 139              6      Delhi  Corporate  Online  2024-08-14 00:00:00    Yes
# 1570             4  Bangalore     Retail   Agent  2021-04-01 00:00:00    Yes
# 732             11     Mumbai    Premium  Online  2024-08-01 00:00:00     No
#
#      Risk_Level Monthly_Spend Transactions  Satisfaction_Score
# 1423       High           NaN            4                 4.6
# 864         Low      13888.22           29                 4.1
# 1150       High      23702.31           54                 5.9
# 1114     Medium      45906.51           26                 9.9
# 1391     Medium       9856.34          112                 1.4
# 828        High      15186.96           31                 7.4
# 1915     Medium       24760.9          132                 1.7
# 139      Medium       6078.54          123                 7.0
# 1570       High      23017.88          110                 2.9
# 732      Medium       14970.5           12                 9.4

# %%
# Q4. Dataset audit
# Use info() to identify:
# • Number of rows
# • Number of columns
# • Columns with missing values
# • Columns having incorrect/object datatypes
# Use: info()

df.info()
df.shape  # count of number of rows and columns
df.size   # counts the number of total values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2040 entries, 0 to 2039
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         2040 non-null   int64
#  1   Age                 1957 non-null   object
#  2   Annual_Income       1933 non-null   object
#  3   Account_Balance     1912 non-null   object
#  4   Credit_Score        2036 non-null   object
#  5   Tenure_Years        2040 non-null   int64
#  6   City                1959 non-null   object
#  7   Segment             1935 non-null   object
#  8   Channel             2040 non-null   object
#  9   Join_Date           1938 non-null   object
#  10  Active              1981 non-null   object
#  11  Risk_Level          2040 non-null   object
#  12  Monthly_Spend       1931 non-null   object
#  13  Transactions        2038 non-null   object
#  14  Satisfaction_Score  1955 non-null   float64
# dtypes: float64(1), int64(2), object(12)
# memory usage: 239.2+ KB
# 30600

# %%
# Q5. Missing-value audit
# Calculate the number of missing values in every column.
# Then verify the result using both:
# isnull()
# and
# isna()

df.isnull().sum()
# Out:
# Customer_ID             0
# Age                    83
# Annual_Income         107
# Account_Balance       128
# Credit_Score            4
# Tenure_Years            0
# City                   81
# Segment               105
# Channel                 0
# Join_Date             102
# Active                 59
# Risk_Level              0
# Monthly_Spend         109
# Transactions            2
# Satisfaction_Score     85
# dtype: int64

# %%
df.isna().sum()
# Out:
# Customer_ID             0
# Age                    83
# Annual_Income         107
# Account_Balance       128
# Credit_Score            4
# Tenure_Years            0
# City                   81
# Segment               105
# Channel                 0
# Join_Date             102
# Active                 59
# Risk_Level              0
# Monthly_Spend         109
# Transactions            2
# Satisfaction_Score     85
# dtype: int64

# %%
# Q6. Duplicate investigation
# Find how many duplicate rows exist.
# Do not remove them yet.
# Use: duplicated()

df.duplicated().sum()
# Out:
# np.int64(40)

# %%
# Q7. Remove duplicates
# Remove all duplicate records and store the cleaned result back into df.
# Then verify that duplicates no longer exist.
# Use: drop_duplicates(), duplicated()
df1 = df.drop_duplicates()
df1
# Out:
#       Customer_ID Age Annual_Income Account_Balance Credit_Score  \
# 0          101317  55         44033       111350.85          772
# 1          101001  32        215546       254378.37          374
# 2          101069  23        226403       159975.42          668
# 3          101968  66         87824        295741.6          315
# 4          100530  67         31570       242423.78          370
# ...           ...  ..           ...             ...          ...
# 2035       101131  42         88530       153490.72          677
# 2036       101295  31        205738        270989.4          392
# 2037       100861  25        211994       160507.65          737
# 2038       101460  64         30105        32117.15          794
# 2039       101127  55        248332       274980.99          783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level Monthly_Spend Transactions  Satisfaction_Score
# 0           Low      23066.19          135                 3.1
# 1          High           NaN          106                 8.2
# 2        Medium      28536.34          146                 6.3
# 3          High      12869.71          115                 9.7
# 4          High      34163.02           94                 3.7
# ...         ...           ...          ...                 ...
# 2035     Medium       8455.42          119                 8.6
# 2036       High      34087.69          134                 2.6
# 2037        Low      26518.74           87                 1.3
# 2038        Low      20943.11          107                 9.3
# 2039        Low      48511.32          119                 3.1
#
# [2000 rows x 15 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(40)

# %%
# Q8. Numeric column investigation
# Select only numeric columns.
# Identify which columns are currently numeric and which potentially numeric columns have
# become object because of invalid values.
# Use: select_dtypes()

df.select_dtypes(int).sum()
df.select_dtypes(float).sum()
# Out:
# Satisfaction_Score    10940.0
# dtype: float64

# %%
# Q9. Fix Age
# The Age column contains:
# • Valid numbers
# • Missing values
# • Invalid text such as unknown, N/A, etc.
# Convert Age into a proper numeric column.
# Invalid values should become missing values.
# Then fill missing Age values using the median age.
# Use: pd.to_numeric(), median(), fillna()

df
# Out:
#       Customer_ID Age Annual_Income Account_Balance Credit_Score  \
# 0          101317  55         44033       111350.85          772
# 1          101001  32        215546       254378.37          374
# 2          101069  23        226403       159975.42          668
# 3          101968  66         87824        295741.6          315
# 4          100530  67         31570       242423.78          370
# ...           ...  ..           ...             ...          ...
# 2035       101131  42         88530       153490.72          677
# 2036       101295  31        205738        270989.4          392
# 2037       100861  25        211994       160507.65          737
# 2038       101460  64         30105        32117.15          794
# 2039       101127  55        248332       274980.99          783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level Monthly_Spend Transactions  Satisfaction_Score
# 0           Low      23066.19          135                 3.1
# 1          High           NaN          106                 8.2
# 2        Medium      28536.34          146                 6.3
# 3          High      12869.71          115                 9.7
# 4          High      34163.02           94                 3.7
# ...         ...           ...          ...                 ...
# 2035     Medium       8455.42          119                 8.6
# 2036       High      34087.69          134                 2.6
# 2037        Low      26518.74           87                 1.3
# 2038        Low      20943.11          107                 9.3
# 2039        Low      48511.32          119                 3.1
#
# [2040 rows x 15 columns]

# %%
df["Age"]= pd.to_numeric(df["Age"],errors = "coerce")
df
# Out:
#       Customer_ID   Age Annual_Income Account_Balance Credit_Score  \
# 0          101317  55.0         44033       111350.85          772
# 1          101001  32.0        215546       254378.37          374
# 2          101069  23.0        226403       159975.42          668
# 3          101968  66.0         87824        295741.6          315
# 4          100530  67.0         31570       242423.78          370
# ...           ...   ...           ...             ...          ...
# 2035       101131  42.0         88530       153490.72          677
# 2036       101295  31.0        205738        270989.4          392
# 2037       100861  25.0        211994       160507.65          737
# 2038       101460  64.0         30105        32117.15          794
# 2039       101127  55.0        248332       274980.99          783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level Monthly_Spend Transactions  Satisfaction_Score
# 0           Low      23066.19          135                 3.1
# 1          High           NaN          106                 8.2
# 2        Medium      28536.34          146                 6.3
# 3          High      12869.71          115                 9.7
# 4          High      34163.02           94                 3.7
# ...         ...           ...          ...                 ...
# 2035     Medium       8455.42          119                 8.6
# 2036       High      34087.69          134                 2.6
# 2037        Low      26518.74           87                 1.3
# 2038        Low      20943.11          107                 9.3
# 2039        Low      48511.32          119                 3.1
#
# [2040 rows x 15 columns]

# %%
age_median = df['Age'].median()
age_median
# Out:
# 47.0

# %%
df['Age'] = df['Age'].fillna(age_median)
df['Age'] = df['Age'].astype("int")
df['Age']
# Out:
# 0       55
# 1       32
# 2       23
# 3       66
# 4       67
#         ..
# 2035    42
# 2036    31
# 2037    25
# 2038    64
# 2039    55
# Name: Age, Length: 2040, dtype: int64

# %%
# Q10. Fix Annual Income
# Clean Annual_Income.
# Requirements:
# 1. Convert invalid values to missing.
# 2. Convert the column to a numeric datatype.
# 3. Calculate the median.
# 4. Fill missing values using the median.
# Use: pd.to_numeric(), median(), fillna(), astype()

df["Annual_Income"]= pd.to_numeric(df["Annual_Income"],errors = "coerce")
df
# Out:
#       Customer_ID  Age  Annual_Income Account_Balance Credit_Score  \
# 0          101317   55        44033.0       111350.85          772
# 1          101001   32       215546.0       254378.37          374
# 2          101069   23       226403.0       159975.42          668
# 3          101968   66        87824.0        295741.6          315
# 4          100530   67        31570.0       242423.78          370
# ...           ...  ...            ...             ...          ...
# 2035       101131   42        88530.0       153490.72          677
# 2036       101295   31       205738.0        270989.4          392
# 2037       100861   25       211994.0       160507.65          737
# 2038       101460   64        30105.0        32117.15          794
# 2039       101127   55       248332.0       274980.99          783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level Monthly_Spend Transactions  Satisfaction_Score
# 0           Low      23066.19          135                 3.1
# 1          High           NaN          106                 8.2
# 2        Medium      28536.34          146                 6.3
# 3          High      12869.71          115                 9.7
# 4          High      34163.02           94                 3.7
# ...         ...           ...          ...                 ...
# 2035     Medium       8455.42          119                 8.6
# 2036       High      34087.69          134                 2.6
# 2037        Low      26518.74           87                 1.3
# 2038        Low      20943.11          107                 9.3
# 2039        Low      48511.32          119                 3.1
#
# [2040 rows x 15 columns]

# %%
AI = df["Annual_Income"].median()
AI
# Out:
# 139999.5

# %%
df["Annual_Income"] = df["Annual_Income"].fillna(AI)
df["Annual_Income"] = df["Annual_Income"].astype("int")
df["Annual_Income"]
# Out:
# 0        44033
# 1       215546
# 2       226403
# 3        87824
# 4        31570
#          ...
# 2035     88530
# 2036    205738
# 2037    211994
# 2038     30105
# 2039    248332
# Name: Annual_Income, Length: 2040, dtype: int64

# %%
# Q11. Clean Account Balance
# The Account_Balance column contains invalid strings and missing values.
# Clean the column and replace missing values with the mean Account Balance.
# Use:
# • pd.to_numeric()
# • mean()
# • fillna()

df["Account_Balance"]= pd.to_numeric(df["Annual_Income"],errors = "coerce")
df
# Out:
#       Customer_ID  Age  Annual_Income  Account_Balance Credit_Score  \
# 0          101317   55          44033            44033          772
# 1          101001   32         215546           215546          374
# 2          101069   23         226403           226403          668
# 3          101968   66          87824            87824          315
# 4          100530   67          31570            31570          370
# ...           ...  ...            ...              ...          ...
# 2035       101131   42          88530            88530          677
# 2036       101295   31         205738           205738          392
# 2037       100861   25         211994           211994          737
# 2038       101460   64          30105            30105          794
# 2039       101127   55         248332           248332          783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level Monthly_Spend Transactions  Satisfaction_Score
# 0           Low      23066.19          135                 3.1
# 1          High           NaN          106                 8.2
# 2        Medium      28536.34          146                 6.3
# 3          High      12869.71          115                 9.7
# 4          High      34163.02           94                 3.7
# ...         ...           ...          ...                 ...
# 2035     Medium       8455.42          119                 8.6
# 2036       High      34087.69          134                 2.6
# 2037        Low      26518.74           87                 1.3
# 2038        Low      20943.11          107                 9.3
# 2039        Low      48511.32          119                 3.1
#
# [2040 rows x 15 columns]

# %%
AB = df["Account_Balance"].median()
AB
# Out:
# 139999.0

# %%
df["Account_Balance"] = df["Account_Balance"].fillna(AB)
df["Account_Balance"] = df["Account_Balance"].astype("int")
df["Account_Balance"]
# Out:
# 0        44033
# 1       215546
# 2       226403
# 3        87824
# 4        31570
#          ...
# 2035     88530
# 2036    205738
# 2037    211994
# 2038     30105
# 2039    248332
# Name: Account_Balance, Length: 2040, dtype: int64

# %%
# Q12. Clean Credit Score
# Clean Credit_Score.
# Invalid values should become missing.
# Then replace missing values with the median Credit Score.
# Finally convert the column to integer.
# Use:
# • pd.to_numeric()
# • median()
# • fillna()
# • astype()

df["Credit_Score"]= pd.to_numeric(df["Credit_Score"],errors = "coerce")
df
# Out:
#       Customer_ID  Age  Annual_Income  Account_Balance  Credit_Score  \
# 0          101317   55          44033            44033         772.0
# 1          101001   32         215546           215546         374.0
# 2          101069   23         226403           226403         668.0
# 3          101968   66          87824            87824         315.0
# 4          100530   67          31570            31570         370.0
# ...           ...  ...            ...              ...           ...
# 2035       101131   42          88530            88530         677.0
# 2036       101295   31         205738           205738         392.0
# 2037       100861   25         211994           211994         737.0
# 2038       101460   64          30105            30105         794.0
# 2039       101127   55         248332           248332         783.0
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level Monthly_Spend Transactions  Satisfaction_Score
# 0           Low      23066.19          135                 3.1
# 1          High           NaN          106                 8.2
# 2        Medium      28536.34          146                 6.3
# 3          High      12869.71          115                 9.7
# 4          High      34163.02           94                 3.7
# ...         ...           ...          ...                 ...
# 2035     Medium       8455.42          119                 8.6
# 2036       High      34087.69          134                 2.6
# 2037        Low      26518.74           87                 1.3
# 2038        Low      20943.11          107                 9.3
# 2039        Low      48511.32          119                 3.1
#
# [2040 rows x 15 columns]

# %%
cs = df["Credit_Score"].median()
cs
# Out:
# 570.0

# %%
df["Credit_Score"] = df["Credit_Score"].fillna(cs)
df["Credit_Score"]= df["Credit_Score"].astype("int")
df["Credit_Score"]
# Out:
# 0       772
# 1       374
# 2       668
# 3       315
# 4       370
#        ...
# 2035    677
# 2036    392
# 2037    737
# 2038    794
# 2039    783
# Name: Credit_Score, Length: 2040, dtype: int64

# %%
# Q13. Clean Monthly Spend
# Clean Monthly_Spend.
# Then:
# • Convert it to numeric.
# • Replace invalid values.
# • Replace missing values using the median.
# • Make sure the final column is numeric.

df["Monthly_Spend"]= pd.to_numeric(df["Monthly_Spend"],errors = "coerce")
df
# Out:
#       Customer_ID  Age  Annual_Income  Account_Balance  Credit_Score  \
# 0          101317   55          44033            44033           772
# 1          101001   32         215546           215546           374
# 2          101069   23         226403           226403           668
# 3          101968   66          87824            87824           315
# 4          100530   67          31570            31570           370
# ...           ...  ...            ...              ...           ...
# 2035       101131   42          88530            88530           677
# 2036       101295   31         205738           205738           392
# 2037       100861   25         211994           211994           737
# 2038       101460   64          30105            30105           794
# 2039       101127   55         248332           248332           783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level  Monthly_Spend Transactions  Satisfaction_Score
# 0           Low       23066.19          135                 3.1
# 1          High            NaN          106                 8.2
# 2        Medium       28536.34          146                 6.3
# 3          High       12869.71          115                 9.7
# 4          High       34163.02           94                 3.7
# ...         ...            ...          ...                 ...
# 2035     Medium        8455.42          119                 8.6
# 2036       High       34087.69          134                 2.6
# 2037        Low       26518.74           87                 1.3
# 2038        Low       20943.11          107                 9.3
# 2039        Low       48511.32          119                 3.1
#
# [2040 rows x 15 columns]

# %%
ms = df["Monthly_Spend"].median()
ms
# Out:
# 24646.77

# %%
df["Monthly_Spend"] = df["Monthly_Spend"].fillna(ms)
df["Monthly_Spend"] = df["Monthly_Spend"].astype("int")
df["Monthly_Spend"]
# Out:
# 0       23066
# 1       24646
# 2       28536
# 3       12869
# 4       34163
#         ...
# 2035     8455
# 2036    34087
# 2037    26518
# 2038    20943
# 2039    48511
# Name: Monthly_Spend, Length: 2040, dtype: int64

# %%
# Q14. Clean Transactions
# The Transactions column contains invalid strings.
# Convert it to numeric and replace invalid values with the median number of transactions.
# Then convert the final column to integer.

df["Transactions"]= pd.to_numeric(df["Transactions"],errors = "coerce")
df
# Out:
#       Customer_ID  Age  Annual_Income  Account_Balance  Credit_Score  \
# 0          101317   55          44033            44033           772
# 1          101001   32         215546           215546           374
# 2          101069   23         226403           226403           668
# 3          101968   66          87824            87824           315
# 4          100530   67          31570            31570           370
# ...           ...  ...            ...              ...           ...
# 2035       101131   42          88530            88530           677
# 2036       101295   31         205738           205738           392
# 2037       100861   25         211994           211994           737
# 2038       101460   64          30105            30105           794
# 2039       101127   55         248332           248332           783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level  Monthly_Spend  Transactions  Satisfaction_Score
# 0           Low          23066         135.0                 3.1
# 1          High          24646         106.0                 8.2
# 2        Medium          28536         146.0                 6.3
# 3          High          12869         115.0                 9.7
# 4          High          34163          94.0                 3.7
# ...         ...            ...           ...                 ...
# 2035     Medium           8455         119.0                 8.6
# 2036       High          34087         134.0                 2.6
# 2037        Low          26518          87.0                 1.3
# 2038        Low          20943         107.0                 9.3
# 2039        Low          48511         119.0                 3.1
#
# [2040 rows x 15 columns]

# %%
ts = df["Transactions"].median()
ts
# Out:
# 76.0

# %%
df["Transactions"] = df["Transactions"].fillna(ts)
df["Transactions"] = df["Transactions"].astype("int")
df["Transactions"]
# Out:
# 0       135
# 1       106
# 2       146
# 3       115
# 4        94
#        ...
# 2035    119
# 2036    134
# 2037     87
# 2038    107
# 2039    119
# Name: Transactions, Length: 2040, dtype: int64

# %%
# Q15. Clean Satisfaction Score
# Clean Satisfaction_Score.
# Replace missing/invalid values using the mean Satisfaction Score.
# Then convert the column to float.

df["Satisfaction_Score"]=pd.to_numeric(df["Satisfaction_Score"], errors = "coerce")
df
# Out:
#       Customer_ID  Age  Annual_Income  Account_Balance  Credit_Score  \
# 0          101317   55          44033            44033           772
# 1          101001   32         215546           215546           374
# 2          101069   23         226403           226403           668
# 3          101968   66          87824            87824           315
# 4          100530   67          31570            31570           370
# ...           ...  ...            ...              ...           ...
# 2035       101131   42          88530            88530           677
# 2036       101295   31         205738           205738           392
# 2037       100861   25         211994           211994           737
# 2038       101460   64          30105            30105           794
# 2039       101127   55         248332           248332           783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level  Monthly_Spend  Transactions  Satisfaction_Score
# 0           Low          23066           135                 3.1
# 1          High          24646           106                 8.2
# 2        Medium          28536           146                 6.3
# 3          High          12869           115                 9.7
# 4          High          34163            94                 3.7
# ...         ...            ...           ...                 ...
# 2035     Medium           8455           119                 8.6
# 2036       High          34087           134                 2.6
# 2037        Low          26518            87                 1.3
# 2038        Low          20943           107                 9.3
# 2039        Low          48511           119                 3.1
#
# [2040 rows x 15 columns]

# %%
ss = df["Satisfaction_Score"].mean()

df["Satisfaction_Score"] = df["Satisfaction_Score"].fillna(ss)
df["Satisfaction_Score"] = df["Satisfaction_Score"].astype("float")
df["Satisfaction_Score"]
# Out:
# 0       3.1
# 1       8.2
# 2       6.3
# 3       9.7
# 4       3.7
#        ...
# 2035    8.6
# 2036    2.6
# 2037    1.3
# 2038    9.3
# 2039    3.1
# Name: Satisfaction_Score, Length: 2040, dtype: float64

# %%
# Q16. Investigate Join_Date
# Inspect the Join_Date column.
# Identify the problems caused by:
# • Missing dates
# • Different date formats
# • Invalid date strings
# Do not clean it yet.

df["Join_Date"].isna().sum()
# Out:
# np.int64(102)

# %%
df['Join_Date'].unique()
# Out:
# array(['2022-08-15 00:00:00', '2025-01-11 00:00:00',
#        '2024-08-01 00:00:00', ..., '2025-09-10 00:00:00',
#        '2022-10-17 00:00:00', '2023-08-26 00:00:00'],
#       shape=(1226,), dtype=object)

# %%
dates = pd.to_datetime(df['Join_Date'], errors='coerce')
dates
# Out:
# 0      2022-08-15
# 1      2025-01-11
# 2      2024-08-01
# 3      2021-05-15
# 4      2026-02-03
#           ...
# 2035   2021-07-10
# 2036   2025-07-05
# 2037   2022-10-17
# 2038   2023-08-26
# 2039          NaT
# Name: Join_Date, Length: 2040, dtype: datetime64[ns]

# %%
# Q17. Convert Join_Date
# Convert Join_Date into a proper Pandas datetime column.
# Any invalid dates should become missing values.
# Use: pd.to_datetime()

Join_Date = pd.to_datetime(df['Join_Date'], errors='coerce')
Join_Date
# Out:
# 0      2022-08-15
# 1      2025-01-11
# 2      2024-08-01
# 3      2021-05-15
# 4      2026-02-03
#           ...
# 2035   2021-07-10
# 2036   2025-07-05
# 2037   2022-10-17
# 2038   2023-08-26
# 2039          NaT
# Name: Join_Date, Length: 2040, dtype: datetime64[ns]

# %%
# Q18. Handle missing dates
# After conversion, find how many missing dates remain.
# Then replace missing dates appropriately using a reasonable date-based strategy.
# Out:
# np.int64(102)

# %%
# Q19. Clean City
# The City column contains values such as:
# Mumbai
# mumbai
# Mumbai
# mumbai
# Standardize the values so that logically identical cities are represented consistently.
# Then check the unique frequency distribution.
# Use: replace(), value_counts()

df["City"]
# Out:
# 0       Bangalore
# 1           Delhi
# 2         Chennai
# 3          Mumbai
# 4       bangalore
#           ...
# 2035    Hyderabad
# 2036       Mumbai
# 2037      Kolkata
# 2038    Bangalore
# 2039      Chennai
# Name: City, Length: 2040, dtype: object

# %%
df.replace({'City': {'mumbai':'Mumbai'}},inplace = True)
df["City"].value_counts()
# Out:
# City
# Mumbai       314
# Hyderabad    278
# Delhi        273
# Kolkata      262
# Pune         256
# Chennai      242
# Bangalore    236
# hyderabad     20
# bangalore     18
# pune          18
# delhi         15
# kolkata       14
# chennai       13
# Name: count, dtype: int64

# %%
# Q20. Analyze Segment
# Check the frequency of:
# Retail
# SME
# Corporate
# Premium
# Also determine whether missing values exist.
# Then replace missing Segment values with the most appropriate category based on your
# analysis.
# Use: value_counts(), fillna()

df["Segment"].value_counts()
# Out:
# Segment
# Premium      523
# Retail       481
# Corporate    475
# SME          456
# Name: count, dtype: int64

# %%
ds= "value"
df["Segment"] = df["Segment"].fillna(ds)
df["Segment"]
# Out:
# 0             SME
# 1          Retail
# 2         Premium
# 3         Premium
# 4          Retail
#           ...
# 2035       Retail
# 2036    Corporate
# 2037       Retail
# 2038       Retail
# 2039       Retail
# Name: Segment, Length: 2040, dtype: object

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Premium      523
# Retail       481
# Corporate    475
# SME          456
# value        105
# Name: count, dtype: int64

# %%
# Q21. Clean Active
# Active is supposed to be a binary column, but it contains:
# Yes
# No
# Y
# N
# YES
# NO
# yes
# no
# 1
# 0
#Transform these into a consistent representation:
# Yes
#No
#Then verify the result with value_counts().
#Use: replace(), value_counts()
df
# Out:
#       Customer_ID  Age  Annual_Income  Account_Balance  Credit_Score  \
# 0          101317   55          44033            44033           772
# 1          101001   32         215546           215546           374
# 2          101069   23         226403           226403           668
# 3          101968   66          87824            87824           315
# 4          100530   67          31570            31570           370
# ...           ...  ...            ...              ...           ...
# 2035       101131   42          88530            88530           677
# 2036       101295   31         205738           205738           392
# 2037       100861   25         211994           211994           737
# 2038       101460   64          30105            30105           794
# 2039       101127   55         248332           248332           783
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 0                3  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes
# 1                8      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes
# 2               12    Chennai    Premium   Agent  2024-08-01 00:00:00     No
# 3               14     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes
# 4                4  bangalore     Retail   Agent  2026-02-03 00:00:00     No
# ...            ...        ...        ...     ...                  ...    ...
# 2035            12  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No
# 2036             8     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes
# 2037             8    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes
# 2038             8  Bangalore     Retail   Agent  2023-08-26 00:00:00     No
# 2039             6    Chennai     Retail  Branch                  NaN    Yes
#
#      Risk_Level  Monthly_Spend  Transactions  Satisfaction_Score
# 0           Low          23066           135                 3.1
# 1          High          24646           106                 8.2
# 2        Medium          28536           146                 6.3
# 3          High          12869           115                 9.7
# 4          High          34163            94                 3.7
# ...         ...            ...           ...                 ...
# 2035     Medium           8455           119                 8.6
# 2036       High          34087           134                 2.6
# 2037        Low          26518            87                 1.3
# 2038        Low          20943           107                 9.3
# 2039        Low          48511           119                 3.1
#
# [2040 rows x 15 columns]

# %%
df["Active"].value_counts()
# Out:
# Active
# Yes    1313
# No      546
# 0        17
# Y        17
# N        16
# no       16
# NO       15
# YES      15
# yes      14
# 1        12
# Name: count, dtype: int64

# %%
df.replace({'Active': {'0':'No', '1':'Yes', 'Y':'Yes', 'N':'No', 'yes':'Yes', 'no':'No'}},inplace = True)
df["Active"].value_counts()
# Out:
# Active
# Yes    1356
# No      595
# NO       15
# YES      15
# Name: count, dtype: int64

# %%
# Q22. Clean Risk_Level
# Check the distribution of:
# High
# Medium
# Low
# Verify whether missing values exist.
# Then display the final class distribution.

df["Risk_Level"].value_counts()
# Out:
# Risk_Level
# High      1009
# Low        548
# Medium     483
# Name: count, dtype: int64

# %%
n1 = "missing value"
df["Risk_Level"] = df["Risk_Level"].fillna(n1)
df["Risk_Level"].value_counts()
# Out:
# Risk_Level
# High      1009
# Low        548
# Medium     483
# Name: count, dtype: int64

# %%
# Q23. Rename columns
# Rename these columns:
# Customer_ID → Customer_ID
# Annual_Income → AnnualIncome
# Account_Balance → AccountBalance
# Credit_Score → CreditScore
# Tenure_Years → Tenure
# Join_Date → CustomerJoinDate
# Risk_Level → RiskLevel
# Monthly_Spend → MonthlySpend
# Satisfaction_Score → SatisfactionScore
# Use rename().

df.rename(columns ={"Customer_ID":"Customer_ID",
                    "Annual_Income":"AnnualIncome",
                    "Credit_Score":"CreditScore",
                    "Tenure_Years":"Tenure",
                    "Join_Date":"CustomerJoinDate",
                    "Risk_Level":"RiskLevel",
                    "Monthly_Spend":"MonthlySpend",
                    "Satisfaction_Score":"SatisfactionScore"}, inplace = True)
df
# Out:
#       Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 0          101317   55         44033            44033          772       3
# 1          101001   32        215546           215546          374       8
# 2          101069   23        226403           226403          668      12
# 3          101968   66         87824            87824          315      14
# 4          100530   67         31570            31570          370       4
# ...           ...  ...           ...              ...          ...     ...
# 2035       101131   42         88530            88530          677      12
# 2036       101295   31        205738           205738          392       8
# 2037       100861   25        211994           211994          737       8
# 2038       101460   64         30105            30105          794       8
# 2039       101127   55        248332           248332          783       6
#
#            City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 0     Bangalore        SME   Agent  2022-08-15 00:00:00    Yes       Low
# 1         Delhi     Retail   Agent  2025-01-11 00:00:00    Yes      High
# 2       Chennai    Premium   Agent  2024-08-01 00:00:00     No    Medium
# 3        Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes      High
# 4     bangalore     Retail   Agent  2026-02-03 00:00:00     No      High
# ...         ...        ...     ...                  ...    ...       ...
# 2035  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No    Medium
# 2036     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes      High
# 2037    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes       Low
# 2038  Bangalore     Retail   Agent  2023-08-26 00:00:00     No       Low
# 2039    Chennai     Retail  Branch                  NaN    Yes       Low
#
#       MonthlySpend  Transactions  SatisfactionScore
# 0            23066           135                3.1
# 1            24646           106                8.2
# 2            28536           146                6.3
# 3            12869           115                9.7
# 4            34163            94                3.7
# ...            ...           ...                ...
# 2035          8455           119                8.6
# 2036         34087           134                2.6
# 2037         26518            87                1.3
# 2038         20943           107                9.3
# 2039         48511           119                3.1
#
# [2040 rows x 15 columns]

# %%
# Q24. Add a prefix
# Add:
# Customer_
# to every column.
# Example:
# Age
# becomes:
# Customer_Age
# Use: add_prefix()

df.add_prefix("Customer_")
# Out:
#       Customer_Customer_ID  Customer_Age  Customer_AnnualIncome  \
# 0                   101317            55                  44033
# 1                   101001            32                 215546
# 2                   101069            23                 226403
# 3                   101968            66                  87824
# 4                   100530            67                  31570
# ...                    ...           ...                    ...
# 2035                101131            42                  88530
# 2036                101295            31                 205738
# 2037                100861            25                 211994
# 2038                101460            64                  30105
# 2039                101127            55                 248332
#
#       Customer_Account_Balance  Customer_CreditScore  Customer_Tenure  \
# 0                        44033                   772                3
# 1                       215546                   374                8
# 2                       226403                   668               12
# 3                        87824                   315               14
# 4                        31570                   370                4
# ...                        ...                   ...              ...
# 2035                     88530                   677               12
# 2036                    205738                   392                8
# 2037                    211994                   737                8
# 2038                     30105                   794                8
# 2039                    248332                   783                6
#
#      Customer_City Customer_Segment Customer_Channel  \
# 0        Bangalore              SME            Agent
# 1            Delhi           Retail            Agent
# 2          Chennai          Premium            Agent
# 3           Mumbai          Premium            Agent
# 4        bangalore           Retail            Agent
# ...            ...              ...              ...
# 2035     Hyderabad           Retail            Agent
# 2036        Mumbai        Corporate            Agent
# 2037       Kolkata           Retail           Online
# 2038     Bangalore           Retail            Agent
# 2039       Chennai           Retail           Branch
#
#      Customer_CustomerJoinDate Customer_Active Customer_RiskLevel  \
# 0          2022-08-15 00:00:00             Yes                Low
# 1          2025-01-11 00:00:00             Yes               High
# 2          2024-08-01 00:00:00              No             Medium
# 3          2021-05-15 00:00:00             Yes               High
# 4          2026-02-03 00:00:00              No               High
# ...                        ...             ...                ...
# 2035       2021-07-10 00:00:00              No             Medium
# 2036       2025-07-05 00:00:00             Yes               High
# 2037       2022-10-17 00:00:00             Yes                Low
# 2038       2023-08-26 00:00:00              No                Low
# 2039                       NaN             Yes                Low
#
#       Customer_MonthlySpend  Customer_Transactions  Customer_SatisfactionScore
# 0                     23066                    135                         3.1
# 1                     24646                    106                         8.2
# 2                     28536                    146                         6.3
# 3                     12869                    115                         9.7
# 4                     34163                     94                         3.7
# ...                     ...                    ...                         ...
# 2035                   8455                    119                         8.6
# 2036                  34087                    134                         2.6
# 2037                  26518                     87                         1.3
# 2038                  20943                    107                         9.3
# 2039                  48511                    119                         3.1
#
# [2040 rows x 15 columns]

# %%
# Q25. Remove unnecessary column
# Determine whether Customer_ID should be retained for analysis.
# Create a cleaned DataFrame without the identifier column.
# Use: drop()

df["Customer_ID"].value_counts()
# Out:
# Customer_ID
# 101610    2
# 100375    2
# 100945    2
# 100906    2
# 100030    2
#          ..
# 100907    1
# 101819    1
# 101271    1
# 101188    1
# 101127    1
# Name: count, Length: 2000, dtype: int64

# %%
df_cleaned = df.drop("Customer_ID", axis=1)
df_cleaned
# Out:
#       Age  AnnualIncome  Account_Balance  CreditScore  Tenure       City  \
# 0      55         44033            44033          772       3  Bangalore
# 1      32        215546           215546          374       8      Delhi
# 2      23        226403           226403          668      12    Chennai
# 3      66         87824            87824          315      14     Mumbai
# 4      67         31570            31570          370       4  bangalore
# ...   ...           ...              ...          ...     ...        ...
# 2035   42         88530            88530          677      12  Hyderabad
# 2036   31        205738           205738          392       8     Mumbai
# 2037   25        211994           211994          737       8    Kolkata
# 2038   64         30105            30105          794       8  Bangalore
# 2039   55        248332           248332          783       6    Chennai
#
#         Segment Channel     CustomerJoinDate Active RiskLevel  MonthlySpend  \
# 0           SME   Agent  2022-08-15 00:00:00    Yes       Low         23066
# 1        Retail   Agent  2025-01-11 00:00:00    Yes      High         24646
# 2       Premium   Agent  2024-08-01 00:00:00     No    Medium         28536
# 3       Premium   Agent  2021-05-15 00:00:00    Yes      High         12869
# 4        Retail   Agent  2026-02-03 00:00:00     No      High         34163
# ...         ...     ...                  ...    ...       ...           ...
# 2035     Retail   Agent  2021-07-10 00:00:00     No    Medium          8455
# 2036  Corporate   Agent  2025-07-05 00:00:00    Yes      High         34087
# 2037     Retail  Online  2022-10-17 00:00:00    Yes       Low         26518
# 2038     Retail   Agent  2023-08-26 00:00:00     No       Low         20943
# 2039     Retail  Branch                  NaN    Yes       Low         48511
#
#       Transactions  SatisfactionScore
# 0              135                3.1
# 1              106                8.2
# 2              146                6.3
# 3              115                9.7
# 4               94                3.7
# ...            ...                ...
# 2035           119                8.6
# 2036           134                2.6
# 2037            87                1.3
# 2038           107                9.3
# 2039           119                3.1
#
# [2040 rows x 14 columns]

# %%
# Q26. Create Annual Income in Lakhs
# Create:
# Income_Lakhs
# using:
# AnnualIncome / 100000
# Then check the first 10 records.

df["AnnualIncome"] = pd.to_numeric(df["AnnualIncome"], errors="coerce")

df["Income_Lakhs"] = df["AnnualIncome"] / 100000

df
# Out:
#       Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 0          101317   55         44033            44033          772       3
# 1          101001   32        215546           215546          374       8
# 2          101069   23        226403           226403          668      12
# 3          101968   66         87824            87824          315      14
# 4          100530   67         31570            31570          370       4
# ...           ...  ...           ...              ...          ...     ...
# 2035       101131   42         88530            88530          677      12
# 2036       101295   31        205738           205738          392       8
# 2037       100861   25        211994           211994          737       8
# 2038       101460   64         30105            30105          794       8
# 2039       101127   55        248332           248332          783       6
#
#            City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 0     Bangalore        SME   Agent  2022-08-15 00:00:00    Yes       Low
# 1         Delhi     Retail   Agent  2025-01-11 00:00:00    Yes      High
# 2       Chennai    Premium   Agent  2024-08-01 00:00:00     No    Medium
# 3        Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes      High
# 4     bangalore     Retail   Agent  2026-02-03 00:00:00     No      High
# ...         ...        ...     ...                  ...    ...       ...
# 2035  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No    Medium
# 2036     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes      High
# 2037    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes       Low
# 2038  Bangalore     Retail   Agent  2023-08-26 00:00:00     No       Low
# 2039    Chennai     Retail  Branch                  NaN    Yes       Low
#
#       MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs
# 0            23066           135                3.1       0.44033
# 1            24646           106                8.2       2.15546
# 2            28536           146                6.3       2.26403
# 3            12869           115                9.7       0.87824
# 4            34163            94                3.7       0.31570
# ...            ...           ...                ...           ...
# 2035          8455           119                8.6       0.88530
# 2036         34087           134                2.6       2.05738
# 2037         26518            87                1.3       2.11994
# 2038         20943           107                9.3       0.30105
# 2039         48511           119                3.1       2.48332
#
# [2040 rows x 16 columns]

# %%
# Q27. Create Monthly Income
# Create:
# MonthlyIncome
# using:
# AnnualIncome / 12
# Then create:
# Income_After_Spending
# using:
# MonthlyIncome - MonthlySpend


df["MonthlyIncome"] = df["AnnualIncome"] / 12
df["Income_After_Spending"] = df["MonthlyIncome"] - df["MonthlySpend"]
df
# Out:
#       Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 0          101317   55         44033            44033          772       3
# 1          101001   32        215546           215546          374       8
# 2          101069   23        226403           226403          668      12
# 3          101968   66         87824            87824          315      14
# 4          100530   67         31570            31570          370       4
# ...           ...  ...           ...              ...          ...     ...
# 2035       101131   42         88530            88530          677      12
# 2036       101295   31        205738           205738          392       8
# 2037       100861   25        211994           211994          737       8
# 2038       101460   64         30105            30105          794       8
# 2039       101127   55        248332           248332          783       6
#
#            City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 0     Bangalore        SME   Agent  2022-08-15 00:00:00    Yes       Low
# 1         Delhi     Retail   Agent  2025-01-11 00:00:00    Yes      High
# 2       Chennai    Premium   Agent  2024-08-01 00:00:00     No    Medium
# 3        Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes      High
# 4     bangalore     Retail   Agent  2026-02-03 00:00:00     No      High
# ...         ...        ...     ...                  ...    ...       ...
# 2035  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No    Medium
# 2036     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes      High
# 2037    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes       Low
# 2038  Bangalore     Retail   Agent  2023-08-26 00:00:00     No       Low
# 2039    Chennai     Retail  Branch                  NaN    Yes       Low
#
#       MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  \
# 0            23066           135                3.1       0.44033
# 1            24646           106                8.2       2.15546
# 2            28536           146                6.3       2.26403
# 3            12869           115                9.7       0.87824
# 4            34163            94                3.7       0.31570
# ...            ...           ...                ...           ...
# 2035          8455           119                8.6       0.88530
# 2036         34087           134                2.6       2.05738
# 2037         26518            87                1.3       2.11994
# 2038         20943           107                9.3       0.30105
# 2039         48511           119                3.1       2.48332
#
#       MonthlyIncome  Income_After_Spending
# 0       3669.416667          -19396.583333
# 1      17962.166667           -6683.833333
# 2      18866.916667           -9669.083333
# 3       7318.666667           -5550.333333
# 4       2630.833333          -31532.166667
# ...             ...                    ...
# 2035    7377.500000           -1077.500000
# 2036   17144.833333          -16942.166667
# 2037   17666.166667           -8851.833333
# 2038    2508.750000          -18434.250000
# 2039   20694.333333          -27816.666667
#
# [2040 rows x 18 columns]

# %%
# Q28. Create Balance-to-Income Ratio
# Create:
# Balance_Income_Ratio
# using:
# AccountBalance / AnnualIncome
# Then inspect the first 10 rows.
# Think carefully about division by zero and missing values.

df["Balance_Income_Ratio"] = df["Account_Balance"] / df["AnnualIncome"]
df.head(10)
# Out:
#    Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 0       101317   55         44033            44033          772       3
# 1       101001   32        215546           215546          374       8
# 2       101069   23        226403           226403          668      12
# 3       101968   66         87824            87824          315      14
# 4       100530   67         31570            31570          370       4
# 5       101334   68         37087            37087          738       1
# 6       100415   47         67229            67229          464       4
# 7       100983   65        139999           139999          554      15
# 8       100417   63        153267           153267          508       5
# 9       101472   42        139999           139999          556       3
#
#         City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 0  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes       Low
# 1      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes      High
# 2    Chennai    Premium   Agent  2024-08-01 00:00:00     No    Medium
# 3     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes      High
# 4  bangalore     Retail   Agent  2026-02-03 00:00:00     No      High
# 5    Chennai    Premium   Agent  2023-06-04 00:00:00    Yes       Low
# 6    Chennai     Retail  Online  2024-01-16 00:00:00    Yes      High
# 7    Kolkata        SME   Agent  2024-06-26 00:00:00    Yes    Medium
# 8  Hyderabad    Premium  Mobile  2025-03-12 00:00:00    Yes      High
# 9    Kolkata  Corporate  Mobile  2021-10-07 00:00:00    Yes    Medium
#
#    MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  MonthlyIncome  \
# 0         23066           135                3.1       0.44033    3669.416667
# 1         24646           106                8.2       2.15546   17962.166667
# 2         28536           146                6.3       2.26403   18866.916667
# 3         12869           115                9.7       0.87824    7318.666667
# 4         34163            94                3.7       0.31570    2630.833333
# 5         15121             6                8.5       0.37087    3090.583333
# 6         17655            31                2.8       0.67229    5602.416667
# 7          1720           139                9.7       1.39999   11666.583333
# 8         38043            76                7.1       1.53267   12772.250000
# 9         11472           124                9.1       1.39999   11666.583333
#
#    Income_After_Spending  Balance_Income_Ratio
# 0          -19396.583333                   1.0
# 1           -6683.833333                   1.0
# 2           -9669.083333                   1.0
# 3           -5550.333333                   1.0
# 4          -31532.166667                   1.0
# 5          -12030.416667                   1.0
# 6          -12052.583333                   1.0
# 7            9946.583333                   1.0
# 8          -25270.750000                   1.0
# 9             194.583333                   1.0

# %%
# Q29. Prepare the ML-ready dataset
# Perform the following complete pipeline:
# 1. Load the dataset.
# 2. Inspect the first 10 rows.
# 3. Inspect the last 10 rows.
# 4. Inspect 10 random records.
# 5. Run info().
# 6. Check missing values.
# 7. Check duplicates.
# 8. Remove duplicates.
# 9. Clean all numeric columns.
# 10. Convert invalid numeric values to missing.
# 11. Fill numerical missing values appropriately.
# 12. Convert Join_Date to datetime.
# 13. Handle invalid dates.
# 14. Standardize categorical values.
# 15. Clean the binary Active column.
# 16. Rename the columns.
# 17. Remove unnecessary columns.
# 18. Verify the final datatypes.
# 19. Generate descriptive statistics.
# 20. Check categorical distributions.

df
# Out:
#       Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 0          101317   55         44033            44033          772       3
# 1          101001   32        215546           215546          374       8
# 2          101069   23        226403           226403          668      12
# 3          101968   66         87824            87824          315      14
# 4          100530   67         31570            31570          370       4
# ...           ...  ...           ...              ...          ...     ...
# 2035       101131   42         88530            88530          677      12
# 2036       101295   31        205738           205738          392       8
# 2037       100861   25        211994           211994          737       8
# 2038       101460   64         30105            30105          794       8
# 2039       101127   55        248332           248332          783       6
#
#            City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 0     Bangalore        SME   Agent  2022-08-15 00:00:00    Yes       Low
# 1         Delhi     Retail   Agent  2025-01-11 00:00:00    Yes      High
# 2       Chennai    Premium   Agent  2024-08-01 00:00:00     No    Medium
# 3        Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes      High
# 4     bangalore     Retail   Agent  2026-02-03 00:00:00     No      High
# ...         ...        ...     ...                  ...    ...       ...
# 2035  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No    Medium
# 2036     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes      High
# 2037    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes       Low
# 2038  Bangalore     Retail   Agent  2023-08-26 00:00:00     No       Low
# 2039    Chennai     Retail  Branch                  NaN    Yes       Low
#
#       MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  \
# 0            23066           135                3.1       0.44033
# 1            24646           106                8.2       2.15546
# 2            28536           146                6.3       2.26403
# 3            12869           115                9.7       0.87824
# 4            34163            94                3.7       0.31570
# ...            ...           ...                ...           ...
# 2035          8455           119                8.6       0.88530
# 2036         34087           134                2.6       2.05738
# 2037         26518            87                1.3       2.11994
# 2038         20943           107                9.3       0.30105
# 2039         48511           119                3.1       2.48332
#
#       MonthlyIncome  Income_After_Spending  Balance_Income_Ratio
# 0       3669.416667          -19396.583333                   1.0
# 1      17962.166667           -6683.833333                   1.0
# 2      18866.916667           -9669.083333                   1.0
# 3       7318.666667           -5550.333333                   1.0
# 4       2630.833333          -31532.166667                   1.0
# ...             ...                    ...                   ...
# 2035    7377.500000           -1077.500000                   1.0
# 2036   17144.833333          -16942.166667                   1.0
# 2037   17666.166667           -8851.833333                   1.0
# 2038    2508.750000          -18434.250000                   1.0
# 2039   20694.333333          -27816.666667                   1.0
#
# [2040 rows x 19 columns]

# %%
df.head(10)
# Out:
#    Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 0       101317   55         44033            44033          772       3
# 1       101001   32        215546           215546          374       8
# 2       101069   23        226403           226403          668      12
# 3       101968   66         87824            87824          315      14
# 4       100530   67         31570            31570          370       4
# 5       101334   68         37087            37087          738       1
# 6       100415   47         67229            67229          464       4
# 7       100983   65        139999           139999          554      15
# 8       100417   63        153267           153267          508       5
# 9       101472   42        139999           139999          556       3
#
#         City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 0  Bangalore        SME   Agent  2022-08-15 00:00:00    Yes       Low
# 1      Delhi     Retail   Agent  2025-01-11 00:00:00    Yes      High
# 2    Chennai    Premium   Agent  2024-08-01 00:00:00     No    Medium
# 3     Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes      High
# 4  bangalore     Retail   Agent  2026-02-03 00:00:00     No      High
# 5    Chennai    Premium   Agent  2023-06-04 00:00:00    Yes       Low
# 6    Chennai     Retail  Online  2024-01-16 00:00:00    Yes      High
# 7    Kolkata        SME   Agent  2024-06-26 00:00:00    Yes    Medium
# 8  Hyderabad    Premium  Mobile  2025-03-12 00:00:00    Yes      High
# 9    Kolkata  Corporate  Mobile  2021-10-07 00:00:00    Yes    Medium
#
#    MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  MonthlyIncome  \
# 0         23066           135                3.1       0.44033    3669.416667
# 1         24646           106                8.2       2.15546   17962.166667
# 2         28536           146                6.3       2.26403   18866.916667
# 3         12869           115                9.7       0.87824    7318.666667
# 4         34163            94                3.7       0.31570    2630.833333
# 5         15121             6                8.5       0.37087    3090.583333
# 6         17655            31                2.8       0.67229    5602.416667
# 7          1720           139                9.7       1.39999   11666.583333
# 8         38043            76                7.1       1.53267   12772.250000
# 9         11472           124                9.1       1.39999   11666.583333
#
#    Income_After_Spending  Balance_Income_Ratio
# 0          -19396.583333                   1.0
# 1           -6683.833333                   1.0
# 2           -9669.083333                   1.0
# 3           -5550.333333                   1.0
# 4          -31532.166667                   1.0
# 5          -12030.416667                   1.0
# 6          -12052.583333                   1.0
# 7            9946.583333                   1.0
# 8          -25270.750000                   1.0
# 9             194.583333                   1.0

# %%
df.tail(10)
# Out:
#       Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 2030       100122   41        201611           201611          507      15
# 2031       101639   61        128850           128850          840       9
# 2032       101045   33         88037            88037          449       8
# 2033       101725   43        122756           122756          487       8
# 2034       101096   18        189232           189232          306      10
# 2035       101131   42         88530            88530          677      12
# 2036       101295   31        205738           205738          392       8
# 2037       100861   25        211994           211994          737       8
# 2038       101460   64         30105            30105          794       8
# 2039       101127   55        248332           248332          783       6
#
#            City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 2030  Bangalore        SME   Agent  2024-11-03 00:00:00    Yes      High
# 2031    Kolkata        SME  Mobile  2026-01-15 00:00:00    Yes       Low
# 2032     Mumbai    Premium  Mobile  2022-11-30 00:00:00    Yes      High
# 2033       Pune      value  Mobile  2021-07-04 00:00:00     No      High
# 2034  hyderabad        SME  Mobile  2025-09-10 00:00:00     No      High
# 2035  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No    Medium
# 2036     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes      High
# 2037    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes       Low
# 2038  Bangalore     Retail   Agent  2023-08-26 00:00:00     No       Low
# 2039    Chennai     Retail  Branch                  NaN    Yes       Low
#
#       MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  \
# 2030         18815            58                7.2       2.01611
# 2031         34300            83                5.0       1.28850
# 2032         24646           147                9.7       0.88037
# 2033         10165            14                6.4       1.22756
# 2034         27227            85                5.9       1.89232
# 2035          8455           119                8.6       0.88530
# 2036         34087           134                2.6       2.05738
# 2037         26518            87                1.3       2.11994
# 2038         20943           107                9.3       0.30105
# 2039         48511           119                3.1       2.48332
#
#       MonthlyIncome  Income_After_Spending  Balance_Income_Ratio
# 2030   16800.916667           -2014.083333                   1.0
# 2031   10737.500000          -23562.500000                   1.0
# 2032    7336.416667          -17309.583333                   1.0
# 2033   10229.666667              64.666667                   1.0
# 2034   15769.333333          -11457.666667                   1.0
# 2035    7377.500000           -1077.500000                   1.0
# 2036   17144.833333          -16942.166667                   1.0
# 2037   17666.166667           -8851.833333                   1.0
# 2038    2508.750000          -18434.250000                   1.0
# 2039   20694.333333          -27816.666667                   1.0

# %%
df.sample(10)
# Out:
#       Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 1816       101664   26        233139           233139          740       3
# 210        101721   68        244780           244780          612      15
# 1399       100739   56        139999           139999          417       2
# 199        100307   57         87768            87768          795      15
# 1480       101459   38        212686           212686          348       1
# 111        100240   66        154749           154749          433      11
# 656        101673   62        157970           157970          554      13
# 1963       101391   53        177889           177889          524       8
# 1662       100957   21        207184           207184          843       8
# 1444       101920   47        235223           235223          826      11
#
#            City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 1816    Kolkata  Corporate   Agent  2022-05-01 00:00:00     No       Low
# 210   Bangalore     Retail  Mobile  2024-04-01 00:00:00    Yes    Medium
# 1399    Kolkata     Retail  Online  2023-08-11 00:00:00    Yes      High
# 199     Kolkata  Corporate  Branch  2025-10-27 00:00:00     No       Low
# 1480    Chennai  Corporate   Agent  2023-09-16 00:00:00    Yes      High
# 111     Kolkata     Retail  Mobile  2021-08-18 00:00:00    Yes      High
# 656      Mumbai     Retail  Branch  2025-08-27 00:00:00     No    Medium
# 1963     Mumbai        SME  Online  2021-06-30 00:00:00     No      High
# 1662    Kolkata    Premium   Agent  2023-02-16 00:00:00    Yes       Low
# 1444       Pune        SME  Online  2022-06-28 00:00:00    Yes      High
#
#       MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  \
# 1816         23940           115           5.100000       2.33139
# 210          27489           100           3.600000       2.44780
# 1399          1720            96           5.300000       1.39999
# 199          32050            77           5.800000       0.87768
# 1480         39930            50           3.500000       2.12686
# 111          40317            47           9.700000       1.54749
# 656           7588            86           1.900000       1.57970
# 1963         24044           144           5.595908       1.77889
# 1662         42096           111           5.595908       2.07184
# 1444         38821           146           4.200000       2.35223
#
#       MonthlyIncome  Income_After_Spending  Balance_Income_Ratio
# 1816   19428.250000           -4511.750000                   1.0
# 210    20398.333333           -7090.666667                   1.0
# 1399   11666.583333            9946.583333                   1.0
# 199     7314.000000          -24736.000000                   1.0
# 1480   17723.833333          -22206.166667                   1.0
# 111    12895.750000          -27421.250000                   1.0
# 656    13164.166667            5576.166667                   1.0
# 1963   14824.083333           -9219.916667                   1.0
# 1662   17265.333333          -24830.666667                   1.0
# 1444   19601.916667          -19219.083333                   1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2040 entries, 0 to 2039
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            2040 non-null   int64
#  1   Age                    2040 non-null   int64
#  2   AnnualIncome           2040 non-null   int64
#  3   Account_Balance        2040 non-null   int64
#  4   CreditScore            2040 non-null   int64
#  5   Tenure                 2040 non-null   int64
#  6   City                   1959 non-null   object
#  7   Segment                2040 non-null   object
#  8   Channel                2040 non-null   object
#  9   CustomerJoinDate       1938 non-null   object
#  10  Active                 1981 non-null   object
#  11  RiskLevel              2040 non-null   object
#  12  MonthlySpend           2040 non-null   int64
#  13  Transactions           2040 non-null   int64
#  14  SatisfactionScore      2040 non-null   float64
#  15  Income_Lakhs           2040 non-null   float64
#  16  MonthlyIncome          2040 non-null   float64
#  17  Income_After_Spending  2040 non-null   float64
#  18  Balance_Income_Ratio   2040 non-null   float64
# dtypes: float64(5), int64(8), object(6)
# memory usage: 302.9+ KB

# %%
df.value_counts()
# Out:
# Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  City       Segment    Channel  CustomerJoinDate     Active  RiskLevel  MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  MonthlyIncome  Income_After_Spending  Balance_Income_Ratio
# 101119       64   32099         32099            444          7       Mumbai     Retail     Agent    2023-09-28 00:00:00  No      High       24085         24            5.595908           0.32099       2674.916667    -21410.083333          1.0                     2
# 100129       50   139999        139999           667          13      Pune       Corporate  Online   2025-08-11 00:00:00  No      Medium     45092         115           8.700000           1.39999       11666.583333   -33425.416667          1.0                     2
# 101274       66   139999        139999           626          14      Chennai    Retail     Mobile   2024-05-01 00:00:00  Yes     Medium     28134         129           5.600000           1.39999       11666.583333   -16467.416667          1.0                     2
# 101084       74   170128        170128           632          7       Pune       SME        Agent    2025-12-11 00:00:00  Yes     Medium     21125         128           5.600000           1.70128       14177.333333   -6947.666667           1.0                     2
# 100030       29   139999        139999           389          3       Chennai    SME        Mobile   2024-12-07 00:00:00  Yes     High       24646         64            1.000000           1.39999       11666.583333   -12979.416667          1.0                     2
#                                                                                                                                                                                                                                                                        ..
# 100653       34   71819         71819            373          9       Delhi      SME        Online   2021-02-26 00:00:00  Yes     High       42465         92            9.100000           0.71819       5984.916667    -36480.083333          1.0                     1
# 100652       40   167635        167635           396          8       Hyderabad  Retail     Mobile   2022-11-10 00:00:00  No      High       2429          68            4.800000           1.67635       13969.583333    11540.583333          1.0                     1
# 100651       52   183670        183670           508          6       Kolkata    Corporate  Branch   2024-01-04 00:00:00  Yes     High       13938         115           8.300000           1.83670       15305.833333    1367.833333           1.0                     1
# 100649       68   78551         78551            525          3       Pune       Retail     Branch   2024-10-23 00:00:00  Yes     High       1042          16            9.600000           0.78551       6545.916667     5503.916667           1.0                     1
# 102000       31   79245         79245            324          6       Bangalore  Premium    Online   2025-12-24 00:00:00  Yes     High       5314          16            1.400000           0.79245       6603.750000     1289.750000           1.0                     1
# Name: count, Length: 1774, dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    2000
# True       40
# Name: count, dtype: int64

# %%
df.drop_duplicates()
# Out:
#       Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 0          101317   55         44033            44033          772       3
# 1          101001   32        215546           215546          374       8
# 2          101069   23        226403           226403          668      12
# 3          101968   66         87824            87824          315      14
# 4          100530   67         31570            31570          370       4
# ...           ...  ...           ...              ...          ...     ...
# 2035       101131   42         88530            88530          677      12
# 2036       101295   31        205738           205738          392       8
# 2037       100861   25        211994           211994          737       8
# 2038       101460   64         30105            30105          794       8
# 2039       101127   55        248332           248332          783       6
#
#            City    Segment Channel     CustomerJoinDate Active RiskLevel  \
# 0     Bangalore        SME   Agent  2022-08-15 00:00:00    Yes       Low
# 1         Delhi     Retail   Agent  2025-01-11 00:00:00    Yes      High
# 2       Chennai    Premium   Agent  2024-08-01 00:00:00     No    Medium
# 3        Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes      High
# 4     bangalore     Retail   Agent  2026-02-03 00:00:00     No      High
# ...         ...        ...     ...                  ...    ...       ...
# 2035  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No    Medium
# 2036     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes      High
# 2037    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes       Low
# 2038  Bangalore     Retail   Agent  2023-08-26 00:00:00     No       Low
# 2039    Chennai     Retail  Branch                  NaN    Yes       Low
#
#       MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  \
# 0            23066           135                3.1       0.44033
# 1            24646           106                8.2       2.15546
# 2            28536           146                6.3       2.26403
# 3            12869           115                9.7       0.87824
# 4            34163            94                3.7       0.31570
# ...            ...           ...                ...           ...
# 2035          8455           119                8.6       0.88530
# 2036         34087           134                2.6       2.05738
# 2037         26518            87                1.3       2.11994
# 2038         20943           107                9.3       0.30105
# 2039         48511           119                3.1       2.48332
#
#       MonthlyIncome  Income_After_Spending  Balance_Income_Ratio
# 0       3669.416667          -19396.583333                   1.0
# 1      17962.166667           -6683.833333                   1.0
# 2      18866.916667           -9669.083333                   1.0
# 3       7318.666667           -5550.333333                   1.0
# 4       2630.833333          -31532.166667                   1.0
# ...             ...                    ...                   ...
# 2035    7377.500000           -1077.500000                   1.0
# 2036   17144.833333          -16942.166667                   1.0
# 2037   17666.166667           -8851.833333                   1.0
# 2038    2508.750000          -18434.250000                   1.0
# 2039   20694.333333          -27816.666667                   1.0
#
# [2000 rows x 19 columns]

# %%
df["AnnualIncome"] = pd.to_numeric(df["AnnualIncome"], errors="coerce")

ss = df["SatisfactionScore"].mean()

df["SatisfactionScore"] = df["SatisfactionScore"].fillna(ss)
df["SatisfactionScore"] = df["SatisfactionScore"].astype("float")
df["SatisfactionScore"]
# Out:
# 0       3.1
# 1       8.2
# 2       6.3
# 3       9.7
# 4       3.7
#        ...
# 2035    8.6
# 2036    2.6
# 2037    1.3
# 2038    9.3
# 2039    3.1
# Name: SatisfactionScore, Length: 2040, dtype: float64

# %%
# 12. Convert Join_Date to datetime.
# 13. Handle invalid dates.
# 14. Standardize categorical values.
# 15. Clean the binary Active column.
# 16. Rename the columns.
# 17. Remove unnecessary columns.
# 18. Verify the final datatypes.
# 19. Generate descriptive statistics.
# 20. Check categorical distributions.


df.rename(columns ={"CustomerJoinDate":"datetime"},inplace = True)
df
# Out:
#       Customer_ID  Age  AnnualIncome  Account_Balance  CreditScore  Tenure  \
# 0          101317   55         44033            44033          772       3
# 1          101001   32        215546           215546          374       8
# 2          101069   23        226403           226403          668      12
# 3          101968   66         87824            87824          315      14
# 4          100530   67         31570            31570          370       4
# ...           ...  ...           ...              ...          ...     ...
# 2035       101131   42         88530            88530          677      12
# 2036       101295   31        205738           205738          392       8
# 2037       100861   25        211994           211994          737       8
# 2038       101460   64         30105            30105          794       8
# 2039       101127   55        248332           248332          783       6
#
#            City    Segment Channel             datetime Active RiskLevel  \
# 0     Bangalore        SME   Agent  2022-08-15 00:00:00    Yes       Low
# 1         Delhi     Retail   Agent  2025-01-11 00:00:00    Yes      High
# 2       Chennai    Premium   Agent  2024-08-01 00:00:00     No    Medium
# 3        Mumbai    Premium   Agent  2021-05-15 00:00:00    Yes      High
# 4     bangalore     Retail   Agent  2026-02-03 00:00:00     No      High
# ...         ...        ...     ...                  ...    ...       ...
# 2035  Hyderabad     Retail   Agent  2021-07-10 00:00:00     No    Medium
# 2036     Mumbai  Corporate   Agent  2025-07-05 00:00:00    Yes      High
# 2037    Kolkata     Retail  Online  2022-10-17 00:00:00    Yes       Low
# 2038  Bangalore     Retail   Agent  2023-08-26 00:00:00     No       Low
# 2039    Chennai     Retail  Branch                  NaN    Yes       Low
#
#       MonthlySpend  Transactions  SatisfactionScore  Income_Lakhs  \
# 0            23066           135                3.1       0.44033
# 1            24646           106                8.2       2.15546
# 2            28536           146                6.3       2.26403
# 3            12869           115                9.7       0.87824
# 4            34163            94                3.7       0.31570
# ...            ...           ...                ...           ...
# 2035          8455           119                8.6       0.88530
# 2036         34087           134                2.6       2.05738
# 2037         26518            87                1.3       2.11994
# 2038         20943           107                9.3       0.30105
# 2039         48511           119                3.1       2.48332
#
#       MonthlyIncome  Income_After_Spending  Balance_Income_Ratio
# 0       3669.416667          -19396.583333                   1.0
# 1      17962.166667           -6683.833333                   1.0
# 2      18866.916667           -9669.083333                   1.0
# 3       7318.666667           -5550.333333                   1.0
# 4       2630.833333          -31532.166667                   1.0
# ...             ...                    ...                   ...
# 2035    7377.500000           -1077.500000                   1.0
# 2036   17144.833333          -16942.166667                   1.0
# 2037   17666.166667           -8851.833333                   1.0
# 2038    2508.750000          -18434.250000                   1.0
# 2039   20694.333333          -27816.666667                   1.0
#
# [2040 rows x 19 columns]

# %%
df["datetime"].value_counts()
# Out:
# datetime
# not_a_date             12
# unknown                 8
# 31/99/2024              6
# 2022-06-26 00:00:00     5
# 2022-07-24 00:00:00     5
#                        ..
# 2024-06-13 00:00:00     1
# 2025-10-10 00:00:00     1
# 2021-08-11 00:00:00     1
# 2023-01-25 00:00:00     1
# 2023-08-26 00:00:00     1
# Name: count, Length: 1225, dtype: int64

# %%
df.describe()
# Out:
#          Customer_ID          Age   AnnualIncome  Account_Balance  \
# count    2040.000000  2040.000000    2040.000000      2040.000000
# mean   100999.696078    47.046569  138410.185784    138410.185784
# std       577.289267    16.201868   61976.064320     61976.064320
# min    100001.000000    18.000000   25163.000000     25163.000000
# 25%    100500.750000    34.000000   88800.500000     88800.500000
# 50%    100999.500000    47.000000  139999.000000    139999.000000
# 75%    101498.250000    61.000000  188679.750000    188679.750000
# max    102000.000000    75.000000  249977.000000    249977.000000
#
#        CreditScore       Tenure  MonthlySpend  Transactions  \
# count  2040.000000  2040.000000   2040.000000   2040.000000
# mean    575.917157     7.566176  24898.325490     75.517157
# std     160.601592     4.614468  13837.407507     42.639630
# min     300.000000     0.000000    559.000000      1.000000
# 25%     434.000000     4.000000  13235.250000     40.000000
# 50%     570.000000     8.000000  24646.000000     76.000000
# 75%     720.000000    12.000000  36371.000000    112.000000
# max     850.000000    15.000000  49942.000000    149.000000
#
#        SatisfactionScore  Income_Lakhs  MonthlyIncome  Income_After_Spending  \
# count        2040.000000   2040.000000    2040.000000            2040.000000
# mean            5.595908      1.384102   11534.182149          -13364.143342
# std             2.523697      0.619761    5164.672027           14822.880883
# min             1.000000      0.251630    2096.916667          -46902.666667
# 25%             3.600000      0.888005    7400.041667          -24620.208333
# 50%             5.595908      1.399990   11666.583333          -12979.416667
# 75%             7.700000      1.886798   15723.312500           -1923.895833
# max            10.000000      2.499770   20831.416667           19643.083333
#
#        Balance_Income_Ratio
# count                2040.0
# mean                    1.0
# std                     0.0
# min                     1.0
# 25%                     1.0
# 50%                     1.0
# 75%                     1.0
# max                     1.0

# %%
df.to_csv("paritosh.csv")

# %%
# Q30 — Ultimate Pandas Cleaning Project
# You are a Data Scientist at a bank. Your raw customer dataset contains 2,000+ records with:
• Missing values
• Duplicate records
• Invalid numerical values
• Mixed datatypes
• Invalid dates
• Mixed date formats
• Inconsistent categorical values
• Binary text inconsistencies
• Unnecessary identifier columns
Your task is to produce a final clean analytical dataset.

Required workflow
Step 1 — Load
pd.read_csv()
Step 2 — Inspect
head()
tail()
sample()
info()

Step 3 — Missing-value analysis
isnull()
isna()

Step 4 — Duplicate handling
duplicated()
drop_duplicates()

Step 5 — Numeric cleaning
Clean:
Age
Annual_Income
Account_Balance
Credit_Score
Monthly_Spend
Transactions
Satisfaction_Score

Use:
pd.to_numeric()
mean()
median()
fillna()
astype()

Step 6 — Date cleaning
Clean:
Join_Date
using:
pd.to_datetime()

Step 7 — Categorical cleaning
Clean:
City
Segment
Channel
Active
Risk_Level
Use:
replace()
value_counts()
fillna()

Step 8 — Column transformation
Use:
rename()
add_prefix()
drop()

Step 9 — Create analytical features
Create at least these:
Income_Lakhs
MonthlyIncome
Income_After_Spending
Balance_Income_Ratio

Step 10 — Final validation
Your final DataFrame must pass these checks:
No duplicate rows
No invalid numeric values
No unexpected object datatype in numeric columns
No invalid dates
No inconsistent Yes/No values
Missing values handled
Column names standardized

Finally display:
head()
tail()
sample()
info()
describe()
value_counts()
