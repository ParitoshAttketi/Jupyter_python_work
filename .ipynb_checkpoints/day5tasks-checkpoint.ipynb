# %%
# Q1 Create a list named students with 5 student names and print it.
students=["paritosh","santosh","veresh","sai","nayan"]
print(students)
# Out:
# ['paritosh', 'santosh', 'veresh', 'sai', 'nayan']

# %%
#Q2 Create a list numbers = [10, 20, 30, 40, 50] and print its type and length using len().
numbers=[10,20,30,40,50]
print(len(numbers),type(numbers))
# Out:
# 5 <class 'list'>

# %%
#Q3 Create an empty list and append 3 numbers into it using append().
list1=[]
list1.append(10)
list1.append(20)
list1.append(30)
list1
# Out:
# [10, 20, 30]

# %%
#Q4 Given lst = [1, 2, 3], use extend() to add [4, 5, 6] to it.
lst=[1, 2, 3]
lst.extend([4, 5, 6])
lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Q5 Use insert() to add number 100 at index 2 in the list [10, 20, 30, 40].
list1=[10, 20, 30, 40]
list1.insert(2,100)
list1
# Out:
# [10, 20, 100, 30, 40]

# %%
#Q6 Remove the element 50 from the list [10, 20, 50, 30, 50] using remove().
list1= [10, 20, 50, 30, 50]
list1.remove(50)
list1.remove(50)
list1
# Out:
# [10, 20, 30]

# %%
#Q7 Use pop() to remove the last element from lst = [5, 10, 15, 20] and print the list.
lst = [5, 10, 15, 20]
lst.pop(-1) # or use pop()
lst
# Out:
# [5, 10, 15]

# %%
#Q8 Clear all elements from the list data = [1, 2, 3, 4, 5] using clear().
list1= [1, 2, 3, 4, 5]
list1.clear()
list1
# Out:
# []

# %%
#Q9 Find the index of 25 in the list [10, 15, 25, 30, 40] using index().
list1 = [10, 15, 25, 30, 40]
list1.index(25)
# Out:
# 2

# %%
list1 = ["apple","mango","banana","orange"]
list1.index("banana")
# Out:
# 2

# %%
#Q10 Count how many times 7 appears in the list [7, 2, 7, 5, 7, 8] using count().
list1= [7, 2, 7, 5, 7, 8] 
list1.count(7)
# Out:
# 3

# %%
#11 Sort the list [45, 12, 78, 23, 56] in ascending order using sort().
list1= [45, 12, 78, 23, 56]
list1.sort()
list1
# Out:
# [12, 23, 45, 56, 78]

# %%
#12 Sort the list [45, 12, 78, 23, 56] in descending order.
list1= [45, 12, 78, 23, 56]
list1.sort(reverse = True)
list1
# Out:
# [78, 56, 45, 23, 12]

# %%
#13 Reverse the list fruits = ["apple", "banana", "mango", "orange"] using reverse().
fruits = ["apple", "banana", "mango", "orange"]
fruits.sort(reverse = True)
fruits
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
#14 Create a copy of list original = [1, 2, 3, 4] using copy() and print both.
original = [1, 2, 3, 4]
original_copy= original.copy()
original_copy
# Out:
# [1, 2, 3, 4]

# %%
#15 Take a sentence from user (e.g. "I love Python programming") and convert it into a list of words using split().
text1=input("enter any sentence :")
text1.split()
# Out:
# enter any sentence : hey this is a string
# ['hey', 'this', 'is', 'a', 'string']

# %%
#16 Create a list of 5 numbers. Append 3 more numbers, then sort it in descending order. 
list1=[10,20,30,40,50]
list1.append(60)
list1.append(61)
list1.append(62)
list1.sort(reverse = True)
list1
# Out:
# [62, 61, 60, 50, 40, 30, 20, 10]

# %%
#17 Create a list. Insert "Python" at index 0, then remove the last element using pop(), and print the length.
name=["santosh","sai","veresh"]
name.insert(0,"Python")
name.pop(-1)
name
# Out:
# ['Python', 'santosh', 'sai']

# %%
#18 Take 5 city names as input from user and store them in a list. Then print them in reverse order.
name1=input("enter 1st city name :")
name2=input("enter 2st city name :")
name3=input("enter 3st city name :")
name4=input("enter 4st city name :")
name5=input("enter 5st city name :")
list_name=[name1,name2,name3,name4,name5]
print(list_name)
list_name.sort(reverse = True)
print(list_name)
# Out:
# enter 1st city name : hyderabad
# enter 2st city name : chennai
# enter 3st city name : goa
# enter 4st city name : mumbai
# enter 5st city name : pune
# ['hyderabad', 'chennai', 'goa', 'mumbai', 'pune']
# ['pune', 'mumbai', 'hyderabad', 'goa', 'chennai']

# %%
#19 Given data = [10, 20, 30, 20, 40, 20], remove all occurrences of 20 (use loop or multiple remove).
data = [10, 20, 30, 20, 40, 20]
data.remove(20)
print(data)
data.remove(20)
print(data)
data.remove(20)
print(data)
# Out:
# [10, 30, 20, 40, 20]
# [10, 30, 40, 20]
# [10, 30, 40]

# %%
#20 Create a list of student marks. Sort it, find the highest and lowest mark using list methods, and print them.
student_marks=[20,30,40,50,15,10]
student_marks.sort()
print(student_marks)
print("highist marks :",student_marks.pop(-1))
print("lowest marks :",student_marks.pop(0))
# Out:
# [10, 15, 20, 30, 40, 50]
# highist marks : 50
# lowest marks : 10
