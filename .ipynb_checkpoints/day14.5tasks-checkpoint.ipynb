# %%
# 1. Student Ranking Challenge (★★★★★)
# You are given:
students = [
{
"name": "Ram",
"marks": {"Math": 80, "Python": 95, "SQL": 88}
},
{
"name": "Amit",
"marks": {"Math": 92, "Python": 90, "SQL": 91}
},
{
"name": "Neha",
"marks": {"Math": 85, "Python": 99, "SQL": 94}
},
{
"name": "Raj",

Sumit Sir Notes
"marks": {"Math": 78, "Python": 70, "SQL": 80}
}
]
# 1. Calculate every student's average.

student_avg = list(map(lambda x: x["name"], "average" : sum(x["marks"]) / len(x["marks"])
