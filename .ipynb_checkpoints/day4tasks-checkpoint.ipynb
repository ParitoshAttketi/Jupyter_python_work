# %%
#Q1
name=input("enter any text")
name.replace(" ","_")
# Out:
# enter any text hey this is paritosh
# 'hey_this_is_paritosh'

# %%
#Q2
name="    paritoh   "
name.strip(" ")
# Out:
# 'paritoh'

# %%
#Q3
name="Hello this is a string"
name.startswith("Hello")
# Out:
# True

# %%
#Q4
name="paritoshattketi@gamil.com"
name.endswith(".com")
# Out:
# True

# %%
#Q5
name="cricket,football,chess"
name.split(",")
# Out:
# ['cricket', 'football', 'chess']

# %%
#Q6
name=["apple","banana","mango"]
" ".join(name)
# Out:
# 'apple banana mango'

# %%
#Q7
name=["Python","is","awesome"]
name[0]=name[0].strip()
name[1]=name[1].strip()
name[2]=name[2].strip()

",".join(name)
# Out:
# 'Python,is,awesome'

# %%
#Q8
name="Rahul kumar Sharma"
name.split(" kumar ")
# Out:
# ['Rahul ', ' Sharma']

# %%
#Q9
name=input("enter any string: ")
name = name.split(" ")
print(name)
print(len(name))
# Out:
# enter any string:  hey this is paritosh
# ['hey', 'this', 'is', 'paritosh']
# 4

# %%
#Q10
name="paritoshattketi@gmail.com"
name.endswith("@gmail.com")
# Out:
# True

# %%
#Q11
name="Hello World Python"
name=name.replace("World","Everyone")
name.split(" ")
# Out:
# ['Hello', 'Everyone', 'Python']

# %%
#Q12
name=input("enter 5 city names: ")
print(name.replace(",","\n"))
# Out:
# enter 5 city names:  a,b,c,d,e
# a
# b
# c
# d
# e

# %%
name=["goa","mumbai","chennai","hyderabad","pune"]
print("\n".join(name))
# Out:
# goa
# mumbai
# chennai
# hyderabad
# pune

# %%
#Q13
name="hello world"
name.strip()
# Out:
# 'hello world'

# %%
name=name.title()
name
# Out:
# 'Hello World'

# %%
name.startswith("Hello")
# Out:
# True

# %%
#Q14
name="he is a bad guy"
print(name.split())
print("".join(name))
print(name.replace("bad","good"))
# Out:
# ['he', 'is', 'a', 'bad', 'guy']
# he is a bad guy
# he is a good guy

# %%
#Q15
name=["10","20","30","40"]
"-".join(name)
# Out:
# '10-20-30-40'

# %%
#Q16
name="hey this is a text"
name=name.split(" ")
name[0].startswith("a") or name[1].startswith("e") or name[2].startswith("i") or name[3].startswith("o") or name[0].startswith("u") 
name[0].startswith("a") or name[1].startswith("e") or name[2].startswith("i") or name[3].startswith("o") or name[0].startswith("u") 
name[0].startswith("a") or name[1].startswith("e") or name[2].startswith("i") or name[3].startswith("o") or name[0].startswith("u") 
name[0].startswith("a") or name[1].startswith("e") or name[2].startswith("i") or name[3].startswith("o") or name[0].startswith("u")
# Out:
# False

# %%
#17
name="hey this is a string"
name=name.replace(" ","-")
print(name)
name=name.split("-")
print(name)
print(len(name[0])>4)
print(len(name[1])>4)
print(len(name[2])>4)
print(len(name[3])>4)
print(len(name[4])>4)
# Out:
# hey-this-is-a-string
# ['hey', 'this', 'is', 'a', 'string']
# False
# False
# False
# False
# True

# %%
#18
name=["paritosh","santosh","nayan","sumit"]
name=",".join(name)
name.replace("paritosh","New student")
# Out:
# 'New student,santosh,nayan,sumit'

# %%
#19
name="hey this is paritosh. we are having lab sessions from 3pm. many people have attened todays session"
print(name.split("."))
print("==================================================================")
print(name.strip())
print("==================================================================")
print("-".join(name))
# Out:
# ['hey this is paritosh', ' we are having lab sessions from 3pm', ' many people have attened todays session']
# ...
# hey this is paritosh. we are having lab sessions from 3pm. many people have attened todays session
# ...
# h-e-y- -t-h-i-s- -i-s- -p-a-r-i-t-o-s-h-.- -w-e- -a-r-e- -h-a-v-i-n-g- -l-a-b- -s-e-s-s-i-o-n-s- -f-r-o-m- -3-p-m-.- -m-a-n-y- -p-e-o-p-l-e- -h-a-v-e- -a-t-t-e-n-e-d- -t-o-d-a-y-s- -s-e-s-s-i-o-n

# %%
#20
name="hey this is a string"
name.replace("string","text")
# Out:
# 'hey this is a text'

# %%
name.strip()
# Out:
# 'hey this is a string'

# %%
name.split()
# Out:
# ['hey', 'this', 'is', 'a', 'string']

# %%
"".join(name)
# Out:
# 'hey this is a string'
