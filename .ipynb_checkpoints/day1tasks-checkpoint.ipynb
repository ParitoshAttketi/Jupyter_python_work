# %%
#python tasks

# name= paritosh, college name= sathyabama uni, course= data science with AI and GenAI

#NAME= paritosh
#COLLEGE NAME= sathyabama
#COURSE NAME= data science
a=str(input("enter ur name: "))
b=str(input("enter ur collage name: "))
c=str(input("enter ur course name: "))

"""The Above are the student details"""
# Out:
# enter ur name:  paritosh
# enter ur collage name:  sathaybama
# enter ur course name:  data science with Ai and GenAi
# 'The Above are the student details'

# %%
#correct the indentation 
if True:
    print("Hello World")
    print("welcome to python")
# Out:
# Hello World
# welcome to python

# %%
#VARIABLES DECLARATION 
name= "paritosh"
age= 23
hight= 6.1
is_student= True
print(name,type(name))
print(age,type(age))
print(hight,type(hight))
print(is_student,type(is_student))
# Out:
# paritosh <class 'str'>
# 23 <class 'int'>
# 6.1 <class 'float'>
# True <class 'bool'>

# %%
#variable naming rules
st_name = 10
my_name = 2
amount= 5
clas=40
MyVar=1
_score= 3
marks= 20

# %%
#ARITHMETIC OPERATORS
a=int(input("enter ur first number: "))
b=int(input("enter ur 2nd number: "))
print("sum:",a+b)
print("difference:",a-b)
print("product:",a*b)
print("divison:",a/b)
print("floor division:",a//b)
print("modulus:",a%b)
print("power:",a**b)
# Out:
# enter ur first number:  20
# enter ur 2nd number:  30
# sum: 50
# difference: -10
# product: 600
# divison: 0.6666666666666666
# floor division: 0
# modulus: 20
# power: 1073741824000000000000000000000000000000

# %%
#comparison operators
a= 10
b= 20
print("equal:",a==b)
print("Not equal:",a!=b)
print("Greater:",a>b)
print("Smaller:",a<b)
print("greater or equal:",a>=b)
print("smaller or equal:",a<=b)
# Out:
# equal: False
# Not equal: True
# Greater: False
# Smaller: True
# greater or equal: False
# smaller or equal: True

# %%
#Assignment Operators
a=10

a += 10
a
# Out:
# 20

# %%
a=10
a -= 10
a
# Out:
# 0

# %%
a=10
a *= 10
a
# Out:
# 100

# %%
a=10
a /= 10
a
# Out:
# 1.0

# %%
a=10
a//=10
a
# Out:
# 1

# %%
a=10
a%=10
a
# Out:
# 0

# %%
a=10
a **= 10
a
# Out:
# 10000000000

# %%
#local and Global variable

college= "Naresh IT"
name=10
if name:
    print(college)
# Out:
# Naresh IT

# %%
#Medium Level 
a=int(input("Enter 1st number:"))
b=int(input("Enter 2nd number:"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# Enter 1st number: 2
# Enter 2nd number: 5
# 7
# -3
# 10
# 0.4
# 0
# 2
# 32

# %%
#temperature converter
#calsius
cal=int(input("enter the value :"))
#fahrenheit
F=(cal* 9/5)+32
print(F)
# Out:
# enter the value : 50
# 122.0

# %%
# area of a circle
radius= float(input("enter the radius :"))
area= 3.14159 * radius**2
print("Area of the circle is :", area)
# Out:
# enter the radius : 5
# Area of the circle is : 78.53975

# %%
## student grade calculator 
a=int(input("enter 1st subject marks:"))
b=int(input("enter 2nd subject marks:"))
c=int(input("enter 3rd subject marks:"))
d=int(input("enter 4th subject marks:"))
e=int(input("enter 5th subject marks:"))
z=a+b+c+d+e
print(z)
z>=90
print("A+")
z>=80
print("A")
z>=70
print("B")
z>=60
print("C")
z>=59
print("Fail")
# Out:
# enter 1st subject marks: 20
# enter 2nd subject marks: 20
# enter 3rd subject marks: 20
# enter 4th subject marks: 10
# enter 5th subject marks: 20
# 90
# A+
# A
# B
# C
# Fail

# %%
#swap two variables
a=int(input("enter value:"))
b=int(input("enter value:"))


temp  = a 

a = b

b = temp

a
# Out:
# enter value: 20
# enter value: 30
# 30

# %%
b
# Out:
# 20

# %%
#swap without var
a=10
b=20
a,b=b,a
a
# Out:
# 20

# %%
b
# Out:
# 10

# %%
#logical operator 
a=int(input("enter the age: "))
b=int(input("enter the salary: "))

a<=18
b>=25000
# Out:
# enter the age:  29
# enter the salary:  10000
# False

# %%
#Dynamic Typing 
x=10
print(x)
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
x=str
x
# Out:
# str
