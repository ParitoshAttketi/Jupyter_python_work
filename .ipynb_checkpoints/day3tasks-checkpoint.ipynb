# %%
#string slicing questions
#Q1
name=str(input("enter any string :"))
print(name[0:5])
# Out:
# enter any string : paritosh
# parit

# %%
#Q2
name="paritosh"
name[-4:]
# Out:
# 'tosh'

# %%
#Q3
name="paritosh"
name[2:8]
# Out:
# 'ritosh'

# %%
name="paritosh"
name[::2]
# Out:
# 'prts'

# %%
name="sumit kumar sharma"
name.title()
# Out:
# 'Sumit Kumar Sharma'

# %%
name
# Out:
# 'sumit kumar sharma'

# %%
name=name.title()
name.find("Sharma")
# Out:
# 12

# %%
print(name[:5])
print(name[12:])
# Out:
# Sumit
# Sharma

# %%
#case conversion 
#Q6
name=str(input("enter any string :"))
print(name.upper())
print(name.lower())
print(name.title())
print(name.capitalize())
# Out:
# enter any string : hello i am paritosh
# HELLO I AM PARITOSH
# hello i am paritosh
# Hello I Am Paritosh
# Hello i am paritosh

# %%
#Q7
name="hey this is paritosh"
print("This is converted :",name.title())
print("This is original :",name)
# Out:
# This is converted : Hey This Is Paritosh
# This is original : hey this is paritosh

# %%
#8
name="HeY ThIS Is PaRiToSh"
print(name.upper())
print(name.lower())
# Out:
# HEY THIS IS PARITOSH
# hey this is paritosh

# %%
name
# Out:
# 'HeY ThIS Is PaRiToSh'

# %%
name=name.upper()
name
# Out:
# 'HEY THIS IS PARITOSH'

# %%
name=name.lower()
name
# Out:
# 'hey this is paritosh'

# %%
#Q9 string cheking methods
name=str(input("enter any string :"))
"contains alphabets" * (name.isalpha() != False) or "Not contains"
# Out:
# enter any string : paritosh
# 'contains alphabets'

# %%
#Q10
name=input("enter any number: ")
"Digit" * (name.isdigit() != False) or "Not Digit"
# Out:
# enter any number:  1000000
# 'Digit'

# %%
#Q11
name= "heythisisparitosh"      ####################################
name.isalnum()
# Out:
# True

# %%
#12
name="paritosh"
name.islower()
# Out:
# True

# %%
#13
pswd=input("enter ur password: ")
"Valid password" *(pswd.isalnum() and len(pswd)>8) or "Invalid password"
# Out:
# enter ur password:  paritosh1234
# 'Valid password'

# %%
pswd = "cnchggxhcg3633"

(pswd.isalnum()) and (len(pswd)>8)
# Out:
# True

# %%
#Q14 find() and index()
name=input("enter a string :")
name.find(name[:1])
# Out:
# enter a string : this is a string
# 0

# %%
#Q15
name="hey this is paritosh"
name.find("paritosh")
# Out:
# 12

# %%
name.find("naresh it")
# Out:
# -1

# %%
#Q16
text= "this is a text for the task"
name.index("is")
# Out:
# 6

# %%
#Q17
text= "this is a string"
name.find("naresh")
# Out:
# -1

# %%
name.index("naresh it")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 name.index("naresh it")
#
# ValueError: substring not found

# %%
#Q18
name="paritosh attketi"
print(name.upper())
print(name.find(" "))
# Out:
# PARITOSH ATTKETI
# 8

# %%
name[:8]
# Out:
# 'paritosh'

# %%
name[-7:]
# Out:
# 'attketi'

# %%
#19
number="9988776655"
len(number)
# Out:
# 10

# %%
print(number.isdigit())
print(len(number))
# Out:
# True
# 10

# %%
#Q20
name=str(input("enter any string :"))
print(name[::-1])
print(name.title())
# Out:
# enter any string : hey this is a string
# gnirts a si siht yeh
# Hey This Is A String
