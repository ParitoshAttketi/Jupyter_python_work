# %%
# Q1 Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?
numbers={1, 2, 3, 2, 4, 1}
print(numbers)
# it doesnt shows dubl numbers
# Out:
# {1, 2, 3, 4}

# %%
# Q2 Create an empty set using correct syntax and add 3 numbers using add().
set1 = set()
set1.add(1)
set1.add(2)
set1.add(3)
print(type(set1),set1)
# Out:
# <class 'set'> {1, 2, 3}

# %%
# Q3 Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().
s = {10, 20, 30}
s.update([40, 50, 60])
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
# Q4 Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.
s = {10, 20, 30, 40}
s.remove(20)
s
# Out:
# {10, 30, 40}

# %%
s = {10, 20, 30, 40}
s.discard(20)
s
# no error if the elements are not present
# Out:
# {10, 30, 40}

# %%
# Q5 Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A.intersection(B)
# Out:
# {3, 4}

# %%
A.difference(B)
# Out:
# {1, 2}

# %%
# Q6 Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.
s = {10, 20, 30, 40}
print(25 in s)
# Out:
# False

# %%
# Q7 Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.
list1=[1, 2, 2, 3, 4, 4, 5] 
set1= set(list1)
print(set1,len(set1))
# Out:
# {1, 2, 3, 4, 5} 5

# %%
# Q8 Take 5 numbers as input from user, store them in a set, and print unique numbers only.
set1 = set()
for i in range(5):
    numb=int(input("enter number:"))
    set1.add(numb)
print(set1)
# Out:
# enter number: 10
# enter number: 20
# enter number: 20
# enter number: 30
# enter number: 50
# {10, 20, 50, 30}

# %%
# Q9 Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.
A = {1, 2, 3}
B = {3, 4, 5}
A.difference(B)
# Out:
# {1, 2}

# %%
# Q10 Create a set and try to add a list [1,2,3] inside it. What happens?
a = set()
a.add([1,2,3])
a
# it shows error (unhashable)

# %%
# Q11 Take age as input. If age >= 18, print "You are eligible to vote".
age=int(input("enter ur age :"))
if age >= 18:
    print("you are elegible to vote.")
else:
    print("you are not elegible to vote")
# Out:
# enter ur age : 17
# you are not elegible to vote

# %%
# Q12 Take a number and check if it is positive, negative, or zero using if-elif- else.
numb=0
if numb >0:
    print("positive")
elif numb < 0:
    print("negitive")
else:print("zero")
# Out:
# zero

# %%
# Q13 Take two numbers and print the larger one using if-else.
a= 10
b= 20
if a > b:
    print(a)
else:
    print(b)
# Out:
# 20

# %%
# Q14 Take a character and check if it is a vowel (a, e, i, o, u) using if statement.
name=input("enter any name")
if name == "a" or name == "e" or name == "i" or name == "o" or name == "u":
    print("it is a vowel")
else:
    print("not a vowel")
# Out:
# enter any name e
# it is a vowel

# %%
# Q15 Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else → Fail.
marks=int(input("enter marks"))
if marks >= 90:
    print(" A grade")
elif marks >= 80:
    print(" B grade")
elif marks >= 70:
    print(" C grade")
else:
    print(" fail")
# Out:
# enter marks 100
#  A grade

# %%
# Q16 Take three numbers and print the largest one using if-elif-else.
numb=int()
for i in range(3):
    int(input("enter number:"))
if numb[
# Out:
# enter number: 10
# enter number: 20
# enter number: 30

# %%
num1=int(input("enter a numb"))
num2=int(input("enter a numb"))
num3=int(input("enter a numb"))
if num1>num2 and num1>num3 == True:
    print(num1,"is largest value")
elif num2>num1 and num2>num3 == True:
    print(num2,"is largest value")
else:
    print(num3,"is largest value")
# Out:
# enter a numb 10
# enter a numb 20
# enter a numb 15
# 15 is largest value

# %%
# Q17 Take a number and check if it is even and greater than 50.
numb=int(input("enter a number"))
if numb % 2 == 0 and numb > 50:
    print(numb," is even and greater then 50")
else:
    print("does not satisfy")
# Out:
# enter a number 52
# 52  is even and greater then 50

# %%
# Q18 Take username and password. If username == "admin" and password =="1234", print "Login Successful", else "Login Failed".
username=input("enter username:")
password=input("enter ur pass:")
if  username == "admin" and password == "1234":
    print("login successful")
else:
    print("login unsucceful")
# Out:
# enter username: admin
# enter ur pass: 1234
# login successful

# %%
# Q19 Take a year as input and check if it is a leap year (divisible by 4 but not 100, or divisible by 400).
year=int(input(""))
if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    print("this is a leap year")
else:
    print("not a leap year")
# Out:
#  2024
# this is a leap year

# %%
# Q20 Take three sides of a triangle and check if they can form a valid triangle(sum of any two sides > third side
ang1=int(input(""))
ang2=int(input(""))
ang3=int(input(""))
if (ang1 + ang2) > ang3:
    print("valid triangle")
else:
    print("not a valid triangle")
# Out:
#  20
#  30
#  40
# valid triangle

# %%
# Q21 Take three numbers as input from the user. Print the largest number and also check whether all three numbers are equal or not.
leng1=int(input(""))
leng2=int(input(""))
leng3=int(input(""))
if leng1>leng2 and leng1>leng3:
    print(leng1,"is largest")
elif leng2>leng1 and leng2>leng3:
    print(leng2,"is largest")
elif leng3>leng1 and leng3>leng2:
    print(leng3,"is largest")
else:
    print("all are equal")
# Out:
#  10
#  20
#  30
# 30 is largest

# %%
# Q22 Take a year as input. Check if it is a leap year or not. (A year is leap if divisible by 4, but not by 100, unless also divisible by 400)
year=int(input(""))
if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    print("this is a leap year")
else:
    print("not a leap year")
# Out:
#  2024
# this is a leap year

# %%
# Q23 Take three sides of a triangle as input. Check if they can form a valid
# triangle (sum of any two sides must be greater than the third side). If valid, also print
# the type (Equilateral, Isosceles, or Scalene).
ang1=int(input(""))
ang2=int(input(""))
ang3=int(input(""))
if (ang1 + ang2) > ang3 and (ang2 + ang3) > ang1 and (ang1 + ang3) > ang2:
    print("valid triangle")
    if ang1 == ang2 == ang3:
        print("Equilateral Triangle")
    elif ang1 == ang2 or ang2 == ang3 or ang1 == ang3:
        print("Isosceles Triangle")
    else:
        print("Scalene Triangle")
else:
    print("not a valid triangle")
# Out:
#  5
#  5
#  6
# valid triangle
# Isosceles Triangle

# %%
# Q24 Take a student's marks in 5 subjects. Calculate percentage and print grade according to these rules:
marks=int(input("enter marks"))
if marks >= 90:
    print(" A+ grade")
elif marks >= 80:
    print(" A grade")
elif marks >= 70:
    print(" B grade")
elif marks >= 60:
    print(" C grade")
else:
    print(" fail")
# Out:
# enter marks 59
#  fail

# %%
# Q25 Take username, password, and age as input.
#If username == "admin" and password == "python123" and age >= 18 → Print "Login Successful"
#Else if age < 18 → Print "You are too young to login"
username=input("enter username:")
password=input("enter ur pass:")
age=int(input("enter ur pass:"))
if  username == "admin" and password == "python123" and age >= 18:
    print("login successful")
else:
    print("login unsucceful")
# Out:
# enter username: admin
# enter ur pass: python123
# enter ur pass: 18
# login successful
