# %% [markdown]
# ### Part A – Abstraction Without super() (1–15)

# %%
# 1. Class Name: Shape
# Problem
# Create an abstract class named Shape.
# Explanation
# A shape can have different formulas for area and perimeter. Therefore, create two abstract
# methods:
# area()
# perimeter()
# Create subclasses like Circle and Rectangle and implement both methods.

from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def calculate_area(self):
        pass

    @abstractmethod
    def calculate_perimeter(self):
        pass

class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius ** 2

    def calculate_perimeter(self):
        return 2 * 3.14 * self.radius

class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

circle = Circle(7)
rectangle = Rectangle(10, 5)

print("Area:", circle.calculate_area())
print("Perimeter:", circle.calculate_perimeter())

print("Area:", rectangle.calculate_area())
print("Perimeter:", rectangle.calculate_perimeter())
# Out:
# Area: 153.86
# Perimeter: 43.96
# Area: 50
# Perimeter: 30

# %%
# 2. Class Name: Vehicle
# Problem
# Create an abstract class named Vehicle.
# Explanation
# Every vehicle can start and stop, but each vehicle does it differently.
# Create two abstract methods:
# start()
# stop()
# Create a Car class that implements both methods.

class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

    def stop(self):
        pass

class Car(Vehicle):
    
    def start(self):
        print("car starts with the start button or with the key manually")
    def stop(self):
        print("car stops when the breaks are applied and turned off")
        
p1 = Car()
p1.start()
p1.stop()
# Out:
# car starts with the start button or with the key manually
# car stops when the breaks are applied and turned off

# %%
# 3. Class Name: Animal
# Problem
# Create an abstract class named Animal.
# Explanation
# Every animal makes a sound, but the sound depends on the animal.
# Create an abstract method:
# make_sound()
# Create subclasses:
# Dog
# Cat
# Each should implement its own sound.

class Animal(ABC):
    
    @abstractmethod
    def make_sound(self):
        pass

class Cat(Animal):
    def make_sound(self):
        print("meoww")

class Dog(Animal):
    def make_sound(self):
        print("bhauu")

p1 = Cat()
p1.make_sound()

p2 = Dog()
p2.make_sound()
# Out:
# meoww
# bhauu

# %%
#4. Class Name: Payment
# Problem
# Create an abstract class named Payment.
# Explanation
# Every payment processes money differently.
# Create an abstract method:
# process_payment(amount)
# Create subclasses:
# CreditCard
# Cash
# Each should process the payment in its own way.

class Payment(ABC):

    @abstractmethod
    def process_payment(self,amount):
        pass

class CreditCard(Payment):
    def process_payment(self,amount):
        if amount > 0:
            print(f"the payment of {amount} has been done successfully with CreditCard")
        else:
            print("amount should be in positive")
class Cash(Payment):
    def process_payment(self,amount):
        print(f"the payment of {amount} has been done with cash successfully")

p1 = CreditCard()
p1.process_payment(1200)

p2 = Cash()
p2.process_payment(500)
# Out:
# the payment of 1200 has been done successfully with CreditCard
# the payment of 500 has been done with cash successfully

# %%
# 5. Class Name: Report
# Problem
# Create an abstract class named Report.
# Explanation
# Different report formats generate reports differently.
# Create an abstract method:
# generate()
# Create:
# PDFReport
# ExcelReport
# Each should generate the report differently.

class Report(ABC):

    @abstractmethod
    def generate(self):
        pass 

class PDFReport(Report):
    def generate(self):
        print("The report has been formated into PDF Report successfully")

class ExcelReport(Report):
    def generate(self):
        print("The report has been formated into Excel Report successfully")

p1 = PDFReport()
p1.generate()

p2 = ExcelReport()
p2.generate()
# Out:
# The report has been formated into PDF Report successfully
# The report has been formated into Excel Report successfully

# %%
# 6. Class Name: BankAccount
# Problem
# Create an abstract class named BankAccount.
# Explanation
# Different bank accounts calculate interest differently.
# Create an abstract method:
# calculate_interest()
# Create:
# SavingsAccount
# Implement the interest calculation.

class BankAccount(ABC):
    @abstractmethod
    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):
    def calculate_interest(self,amount):
        self.amount = amount
        amount = amount * 0.20
        print(f"The interest amount : {amount}")

p1 = SavingsAccount()

p1.calculate_interest(2500)
# Out:
# The interest amount : 500.0

# %%
# 7. Class Name: Device
# Problem
# Create an abstract class named Device.
# Explanation
# Every electronic device can be turned on and off.
# Create abstract methods:
# turn_on()
# turn_off()
# Implement them in a subclass such as Laptop or TV.

class Device(ABC):

    @abstractmethod
    def turn_on(self):
        pass

    def turn_off(self):
        pass

class Laptop(Device):
    def turn_on(self):
        return "laptop is turned on using power button"

    def turn_off(self):
        return "laptop is turned off using the shut down option"

class TV(Device):
    def turn_on(self):
        return "TV is tured on using TV remote"

    def turn_off(self):
        return "TV is tured off using TV remote or power switch"


p1 = Laptop()

print("laptop on: ",p1.turn_on())
print("laptop off: ",p1.turn_off())
p2 = TV()
print("*"*50)
print("TV on: ",p1.turn_on())
print("TV off: ",p1.turn_off())
# Out:
# laptop on:  laptop is turned on using power button
# laptop off:  laptop is turned off using the shut down option
# **************************************************
# TV on:  laptop is turned on using power button
# TV off:  laptop is turned off using the shut down option

# %%
# 8. Class Name: Employee
# Problem
# Create an abstract class named Employee.
# Explanation
# Employees receive bonuses based on their roles.
# Create an abstract method:
# calculate_bonus()
# Create subclass:
# Manager
# Implement the bonus calculation.

class Employee(ABC):

    @abstractmethod
    def calculate_bonus(self):
        pass

class Manager(Employee):
    def calculate_bonus(self,amount):
        self.amount =  amount
        amount += 10000
        print(f"amount with bonus : {amount}")

p1 = Manager()
p1.calculate_bonus(50000)
# Out:
# amount with bonus : 60000

# %%
# 9. Class Name: Transport
# Problem
# Create an abstract class named Transport.
# Explanation
# Every transport moves differently and uses different fuel.
# Create abstract methods:
# move()
# fuel_type()
# Create subclasses like:
# Car
# Train

class Transport(ABC):
    @abstractmethod 
    def move(self):
        pass

    def fuel_type(self):
        pass 
        
class Car(Transport):
    def move(self):
        print("Car travels on the road")

    def fuel_type(self):
        print("car fuel type is petrol")

class Train(Transport):
    def move(self):
        print("Train travels on rail track")

    def fuel_type(self):
        print("train fuel type is cole")

p1 = Car()
p1.move()
p1.fuel_type()

p2 = Train()
p2.move()
p2.fuel_type()
# Out:
# Car travels on the road
# car fuel type is petrol
# Train travels on rail track
# train fuel type is cole

# %%
# 10. Class Name: Notification
# Problem
# Create an abstract class named Notification.
# Explanation
# Notifications can be sent in different ways.
# Create abstract method:
#  send(message)
# Create subclasses:
# EmailNotification
# SMSNotification

class Notification(ABC):
    @abstractmethod
    def send(self):
        pass

class EmailNotification(Notification):
    def send(self):
        print("You have a Email Notification")

class SMSNotification(Notification):
    def send(self):
        print("you have a SMS Notification")

p1 = EmailNotification()
p1.send()
p2 = SMSNotification()
p2.send()
# Out:
# You have a Email Notification
# you have a SMS Notification

# %%
# 11. Class Name: FileHandler
# Problem
# Create an abstract class named FileHandler.
# Explanation
# Files can be read and written differently.
# Create abstract methods:
# read()
# write(data)
# Create subclasses like:
# TextFileHandler
# CSVFileHandler

class FileHandler(ABC):
    @abstractmethod
    def read(self):
        pass

    def write(self,data):
        pass

class TextFileHandler(FileHandler):
    def read(self):
        return "The file is read in Text FileHandler"
    def write(self,data):
        self.data = data
        return f"{self.data}: is written in Text FileHandler"
        
class CSVFileHandler(FileHandler):
    def read(self):
        return "The file is read in CSV FileHandler"
    def write(self,data):
        self.data = data
        return f"{self.data}: is written in CSV FileHandler" 

p1 = TextFileHandler()
print(p1.read())
print(p1.write("paritoshh"))

p2 = CSVFileHandler()
print(p2.read())
print(p2.write("paritosh"))
# Out:
# The file is read in Text FileHandler
# paritoshh: is written in Text FileHandler
# The file is read in CSV FileHandler
# paritosh: is written in CSV FileHandler

# %%
# 12. Class Name: GameCharacter
# Problem
# Create an abstract class named GameCharacter.
# Explanation
# Every game character attacks differently.
# Create abstract method:
# attack()
# Create subclasses:
# Warrior
# Mage

class GameCharacter(ABC):

    @abstractmethod
    def attack(self):
        pass

class Warrior(GameCharacter):
    def attack(self):
        print("Warrior attacks with a sword")

class Mage(GameCharacter):
    def attack(self):
        print("Mage attacks with magical stick")

p1 = Warrior()
p1.attack()
p2 = Mage()
p2.attack()
# Out:
# Warrior attacks with a sword
# Mage attacks with magical stick

# %%
# 13. Class Name: Calculator
# Problem
# Create an abstract class named Calculator.
# Explanation
# Different calculators perform different operations.
# Create abstract method:
# compute(a, b)
# Create subclasses:
# AdditionCalculator
# MultiplicationCalculator

class Calculator(ABC):
    @abstractmethod
    def compute(a,b):
        pass 

class AdditionCalculator(Calculator):
    def compute(self,a,b):
        print(a+b)
class MultiplicationCalculator(Calculator):
    def compute(self,a,b):
        print(a*b)

p1 = AdditionCalculator()
p1.compute(10,5)

p2 = MultiplicationCalculator()
p2.compute(10,5)
# Out:
# 15
# 50

# %%
# 14. Class Name: Database
# Problem
# Create an abstract class named Database.
# Explanation
# Different databases connect and execute queries differently.
# Create abstract methods:
# connect()
# query(sql)
# Create subclasses:
# MySQLDatabase
# MongoDatabase

class Database(ABC):

    @abstractmethod
    def connect(self):
        pass
        
    def query(self, sql):
        pass

class MySQLDatabase(Database):

    def connect(self):
        print("Connected to MySQL Database.")

    def query(self, sql):
        print(f"Executing MySQL Query: {sql}")

class MongoDatabase(Database):

    def connect(self):
        print("Connected to MongoDB Database.")

    def query(self, sql):
        print(f"Executing MongoDB Query: {sql}")

mysql = MySQLDatabase()
mongo = MongoDatabase()

mysql.connect()
mysql.query("data science")

mongo.connect()
mongo.query("ai")
# Out:
# Connected to MySQL Database.
# Executing MySQL Query: data science
# Connected to MongoDB Database.
# Executing MongoDB Query: ai

# %%
# 15. Class Name: Shape3D
# Problem
# Create an abstract class named Shape3D.
# Explanation
# Three-dimensional shapes have different formulas.
# Create abstract methods:
# volume()
# surface_area()
# Create subclasses:
# Cube
# Sphere

class Shape3D(ABC):

    @abstractmethod
    def volume(self):
        pass

    @abstractmethod
    def surface_area(self):
        pass
  
class Cube(Shape3D):
    def __init__(self, side):
        self.side = side

    def volume(self):
        return self.side ** 3

    def surface_area(self):
        return 6 * self.side ** 2

class Sphere(Shape3D):

    def __init__(self, radius):
        self.radius = radius

    def volume(self):
        return (4 / 3) * 3.14 * self.radius ** 3

    def surface_area(self):
        return 4 * 3.14 * self.radius ** 2

class Cylinder(Shape3D):

    def __init__(self, radius, height):
        self.radius = radius
        self.height = height

    def volume(self):
        return 3.14 * self.radius ** 2 * self.height

    def surface_area(self):
        return 2 * 3.14 * self.radius * (self.radius + self.height)
        
cube = Cube(4)
sphere = Sphere(3)
cylinder = Cylinder(3, 5)

print("Volume:", cube.volume())
print("Surface Area:", cube.surface_area())

print("Volume:", sphere.volume())
print("Surface Area:", sphere.surface_area())

print("Volume:", cylinder.volume())
print("Surface Area:", cylinder.surface_area())
# Out:
# Volume: 64
# Surface Area: 96
# Volume: 113.03999999999999
# Surface Area: 113.04
# Volume: 141.3
# Surface Area: 150.72

# %% [markdown]
# ### Part B – Abstraction Using super() (16–30)

# %%
from abc import ABC, abstractmethod

# 16. Class Name: Shape
# Problem
# Create an abstract class named Shape.
# Explanation
# The constructor should accept a shape's color.
# __init__(self, color)
# Create an abstract method:
# area()
# Create subclass:
# Circle
# Use super() to initialize the color.

class Shape(ABC):

    def __init__(self, color):
        self.color = color

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):

    def __init__(self, color, radius):
        super().__init__(color)
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

c1 = Circle("Red", 7)

print("Color:", c1.color)
print("Area:", c1.area())
# Out:
# Color: Red
# Area: 153.86

# %%
# 17. Class Name: Vehicle
# Problem
# Create an abstract class named Vehicle.
# Explanation
# Store the vehicle brand in the constructor.
# __init__(self, brand)
# Create abstract methods:
# start()
# stop()
# Create subclass:
# Car
# Use super() to initialize the brand.

class Vehicle(ABC):
    def __init__(self,brand):
        self.brand = brand

    @abstractmethod
    def start(self):
        pass

    def stop(self):
        pass

class Car(Vehicle):
    
    def __init__(self, brand):
        super().__init__(brand)
         
    def start(self):
        return "car starts when the power us switched on"

    def stop(self):
        return "car stops if the power is switched off"

v1 = Car("kia")
v1.start()
v1.stop()
# Out:
# 'car stops if the power is switched off'

# %%
# 18. Class Name: Animal
# Problem
# Create an abstract class named Animal.
# Explanation
# Store the animal's name in the constructor.
# __init__(self, name)
# Create abstract method:
# make_sound()
# Create subclass:
# Dog
# Use super() to initialize the name.

class Animal(ABC):
    def __init__(self, name):
        self.name =  name

    @abstractmethod
    def make_sound(self):
        pass

class Dog(Animal):
    def __init__(self,name):
        super().__init__(name)

    def make_sound(self):
        return f"{self.name} makes bhauu sound"

doggish = Dog("snow")

doggish.make_sound()
# Out:
# 'snow makes bhauu sound'

# %%
# 19. Class Name: Payment
# Problem
# Create an abstract class named Payment.
# Explanation
# Store the payment amount in the constructor.
# __init__(self, amount)
# Create abstract method:
# process_payment()
# Create subclasses:
# CreditCard
# Cash
# Use super() to initialize the amount.

class Payment(ABC):
    def __init__(self, amount):
        self._amount = amount

    @abstractmethod
    def process_payment(self):
        pass

class CreditCard(Payment):
    def __init__(self, amount):
        super().__init__(amount)

    def process_payment(self):
        return f"Payment has been done through CreditCard : {self._amount}"

class Cash(Payment):
    def __init__(self, amount):
        super().__init__(amount)

    def process_payment(self):
        return f"Payment has been done througth cash : {self._amount}"

p1 = CreditCard(2000)
p1.process_payment()
p2 = Cash(3000)
p2.process_payment()
# Out:
# 'Payment has been done througth cash : 3000'

# %%
# 20. Class Name: Employee
# Problem
# Create an abstract class named Employee.
# Explanation
# Store the employee name.
# __init__(self, name)
# Create abstract method:
# calculate_bonus()
# Create subclass:
# Manager
# Use super() to initialize the name.

class Employee(ABC):
    def __init__(self,name):
        self._name = name

    @abstractmethod
    def calculate_bonus(self):
        pass

class Manager(Employee):
    def __init__(self,name):
        super().__init__(name)

    def calculate_bonus(self,amount):
        self.amount = amount
        return f"manager {self._name} bonus is {self.amount + 20000}"

ep1 = Manager("paritosh")
ep1.calculate_bonus(25000)
# Out:
# 'manager paritosh bonus is 45000'

# %%
# 21. Class Name: Report
# Problem
# Create an abstract class named Report.
# Explanation
# Store the report title.
# __init__(self, title)
# Create abstract method:
# generate()
# Create subclass:
# PDFReport
# Use super() to initialize the title.

class Report(ABC):
    def __init__(self, title):
        self._title = title

    @abstractmethod
    def generate(self):
        pass

class PDFReport(Report):
    def __init__(self,title):
        super().__init__(title)

    def generate(self):
        return f"{self._title} is a PDF Report"

p1 = PDFReport("song of ice and fire")
p1.generate()
# Out:
# 'song of ice and fire is a PDF Report'

# %%
# 22. Class Name: BankAccount
# Problem
# Create an abstract class named BankAccount.
# Explanation
# Store the account balance.
# __init__(self, balance)
# Create abstract method:
# calculate_interest()
# Create subclass:
# SavingsAccount
# Use super() to initialize the balance.

class BankAccount(ABC):
    def __init__(self, balance):
        self._balance = balance

    @abstractmethod
    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):
    def __init__(self,balance):
        super().__init__(balance)

    def calculate_interest(self):
        interest = self._balance * 0.05 
        return interest

account = SavingsAccount(10000)

print("Balance:", account._balance)
print("Interest:", account.calculate_interest())
# Out:
# Balance: 10000
# Interest: 500.0

# %%
# 23. Class Name: Device
# Problem
# Create an abstract class named Device.
# Explanation
# Store the device brand.
# __init__(self, brand)
# Create abstract methods:
# turn_on()
# turn_off()
# Create subclass:
# Laptop
# Use super() to initialize the brand.

class Device(ABC):
    def __init__(self, brand):
        self.brand = brand

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass
        
class Laptop(Device):
    def __init__(self, brand):
        super().__init__(brand)

    def turn_on(self):
        return f"{self.brand} laptop is turned on."

    def turn_off(self):
        return f"{self.brand} laptop is turned off."

l1 = Laptop("Dell")

print("Brand:", l1.brand)
print(l1.turn_on())
print(l1.turn_off())
# Out:
# Brand: Dell
# Dell laptop is turned on.
# Dell laptop is turned off.

# %%
# 24. Class Name: Transport
# Problem
# Create an abstract class named Transport.
# Explanation
# Store the transport speed.
# __init__(self, speed)
# Create abstract methods
# move()
# fuel_type()
# Create subclass:
# Car
# Use super() to initialize the speed.

class Transport(ABC):
    def __init__(self, speed):
        self.speed = speed

    @abstractmethod
    def move(self):
        pass

    def fuel_type(self):
        pass

class Car(Transport):
    def __init__(self, speed):
        super().__init__(speed)

    def move(self):
        return "moves when its starts"

    def fuel_type(self):
        return "Petrol"

p1 = Car("200 kmph")

print(f"{p1.move()}, at speed : {p1.speed}")
print(f"fuel type of Car:{p1.fuel_type()}")
# Out:
# moves when its starts, at speed : 200 kmph
# fuel type of Car:Petrol

# %%
# 25. Class Name: Notification
# Problem
# Create an abstract class named Notification.
# Explanation
# Store the recipient name.
# __init__(self, recipient)
# Create abstract method:
# send(message)
# Create subclass:
# EmailNotification
# Use super() to initialize the recipient.

class Notification(ABC):
    def __init__(self, recipient):
        self.recipient = recipient

    @abstractmethod
    def send(self, message):
        pass
        
class EmailNotification(Notification):
    
    def __init__(self, recipient):
        super().__init__(recipient)

    def send(self, message):
        return f"Email sent to {self.recipient}: {message}"

n1 = EmailNotification("paritosh@gmail.com")

print(n1.send("Your order has been delivered."))
# Out:
# Email sent to paritosh@gmail.com: Your order has been delivered.

# %%
# 26. Class Name: Shape
# Problem
# Create an abstract class named Shape.
# Explanation
# Store the color in the constructor.
# Create abstract method:
# area()
# Create subclass:
# Rectangle
# Use super() to initialize the color and then calculate the area.

class Shape(ABC):
    def __init__(self, color):
        self.color = color

    @abstractmethod
    def area(self):
        pass
        
class Rectangle(Shape):
    def __init__(self, color, length, width):
        super().__init__(color)
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

r1 = Rectangle("Blue", 10, 5)

print("Color:", r1.color)
print("Area:", r1.area())
# Out:
# Color: Blue
# Area: 50

# %%
# 27. Class Name: Employee
# Problem
# Create an abstract class named Employee.
# Explanation
# Store:
# Employee name
# Base salary
# Create abstract method:
# calculate_bonus()
# Create subclass:
# Developer
# Use super() to initialize the common employee information before calculating the bonus.

class Employee(ABC):
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary

    @abstractmethod
    def calculate_bonus(self):
        pass 

class Developer(Employee):
    def __init__(self,name,salary):
        super().__init__(name,salary)

    def calculate_bonus(self):
        bonus = self.salary + self.salary * 0.20
        return bonus

ep = Developer("Paritosh",40000)
print(f"Name of the Employee : {ep.name}")
print(f"Salary without bonus : {ep.salary}")
print(f"Salary with bonus : {ep.calculate_bonus()}")
# Out:
# Name of the Employee : Paritosh
# Salary without bonus : 40000
# Salary with bonus : 48000.0

# %%
# 28. Class Name: Vehicle
# Problem
# Create an abstract class named Vehicle.
# Explanation
# Store the vehicle brand.
# Create a multilevel inheritance structure:
# Vehicle → Car → ElectricCar
# Use super() in each constructor to initialize the parent class data.

class Vehicle(ABC):
    def __init__(self,brand):
        self.brand = brand

    @

# %%
# 29. Class Name: Calculator
# Problem
# Create an abstract class named Calculator.
# Explanation
# Store the calculator name.
# __init__(self, name)
# Create abstract method:
# compute(a, b)
# Create subclass:
# ScientificCalculator
# Use super() to initialize the calculator name.

class Calculator(ABC):
    def __init__(self, name):
        self.name = name

    @abstractmethod
    def compute(self,a,b):
        pass

class ScientificCalculator(Calculator):
    def __init__(self, name):
        super().__init__(name)

    def compute(self,a,b):
        result = a ** b
        return result

c = ScientificCalculator("Casio Calculator")
print(c.name)
print(c.compute(2,5))
# Out:
# Casio Calculator
# 32

# %%
# 30. Class Name: Report
# Problem
# Create an abstract class named Report.
# Explanation
# Store:
# Report title
# Add a normal method:
# show_header()
# Create abstract method:
# generate()
# Create subclasses:
# PDFReport
# HTMLReport
# Use super() to:
# initialize the title using super().__init__()
# call the parent method using super().show_header()
# then generate the report in the subclass.

class Report(ABC):
    def __init__(self,title):
        self.title = title

    def show_header(self):
        return self.title

    @abstractmethod
    def generate(self):
        pass

class PDFReport(Report):
    def __init__(self,name):
        super().__init__(name)
        super().show_header()

    def generate(self):
        return f"{self.title} is in PDFReport formate"

class HTMLReport(Report):
    def __init__(self,name):
        super().__init__(name)
        super().show_header()

    def generate(self):
        return f"{self.title} is in HTMLReport formate"

c1 = PDFReport("Harry Potter")
print(c1.title)
print(c1.generate())

c2 = HTMLReport("Song Of Ice and Fire")
print(c2.title)
print(c2.generate())
# Out:
# Harry Potter
# Harry Potter is in PDFReport formate
# Song Of Ice and Fire
# Song Of Ice and Fire is in HTMLReport formate

# %%
#
